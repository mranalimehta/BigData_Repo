# %% [markdown]
# # Mongo DB task B

# %% [markdown]
# In this task we have two tasks. In the first task we create a two in the mongoDB database and in the second task we have to fetch data from the collection using the find query.

# %% [markdown]
# ## Task B0: Creating a database named 'project_sohail' using PyMongo

# %% [markdown]
# Firstly we have to perform initialization and connection to the MongoDB server using python. This is done using pymongo which is a mongoDB api for python.

# %%
from pymongo import MongoClient

client = MongoClient('localhost')

db = client.project_sohail  #creating a database with the name project_sohail

# %%
import pandas as pd

# %%
df_climate_historic = pd.read_csv("climate_historic.csv")
df_hotspot_historic = pd.read_csv("hotspot_historic.csv")

# %%
df_climate_historic.head()
# Out:
#    station        date  air_temperature_celcius  relative_humidity  \
# 0   948700  31/12/2016                       19               56.8
# 1   948700   2/01/2017                       15               50.7
# 2   948700   3/01/2017                       16               53.6
# 3   948700   4/01/2017                       24               61.6
# 4   948700   5/01/2017                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation   ID
# 0              7.9            11.1          0.00I   1
# 1              9.2            13.0          0.02G   2
# 2              8.1            15.0          0.00G   3
# 3              7.7            14.0          0.00I   4
# 4              7.0            13.0          0.00I   5

# %%
df_hotspot_historic.head()
# Out:
#    latitude  longitude             datetime  confidence        date  \
# 0   -37.966    145.051  2017-12-27T04:16:51          78  27/12/2017
# 1   -35.541    143.311  2017-12-27T00:02:15          82  27/12/2017
# 2   -35.554    143.307  2017-12-27T00:02:15          67  27/12/2017
# 3   -35.543    143.316  2017-12-27T00:02:14          86  27/12/2017
# 4   -37.708    145.100  2017-12-25T04:29:08          80  25/12/2017
#
#    surface_temperature_celcius
# 0                           68
# 1                           63
# 2                           53
# 3                           67
# 4                           54

# %%
# this part of the code is to crete unique ID's for the climate_historic table
id_climate = []
for i in range(1,len(df_climate_historic)+1):
    id_climate.append(i)
df_climate_historic["ID"] = id_climate

# %%
#this part of the code is to create reference ID's for the hotspot_historic table
id_hotspot_historic = []
for i in df_hotspot_historic.index:
    for j in df_climate_historic.index:
        if df_hotspot_historic['date'][i] == df_climate_historic['date'][j]:
            id_hotspot_historic.append(df_climate_historic['ID'][j])

# %%
df_hotspot_historic['Reference_ID'] = id_hotspot_historic

# %% [markdown]
# ## Task B1: Creating two collections using the csv files in the project_sohail database

# %% [markdown]
# Now we have to load the data into the database. In MongoDB all the data is stored in the database in BSON format. Hence firstly we convert all the data we have into dictionary format and then load it into mongoDB collection.

# %%
#creating a collection named climateData and loading climate_historic.csv to it
db.climateData.delete_many({})  #Deleting any collection with this name
records = df_climate_historic.to_dict(orient = 'records') #converting the csv data into dictionary format
db.climateData.insert_many(records)

# %%
#loading hotspot_historic.csv file to the mongoDB database
records = df_hotspot_historic.to_dict(orient='records')
db.hotspot_historic.delete_many({}) #deleting any collection with this name
db.hotspot_historic.insert_many(records) #Here a collection named hotspot_historic would be created

# %% [markdown]
# As of now we have a database named __'project_sohail'__ and in this database we have two collections named __'climateData'__ and __'hotspot_historic'__

# %% [markdown]
# ## Task B2: Fetching of data using PyMongo

# %% [markdown]
# Now we have to start fetching the data which is the second task in task B.

# %% [markdown]
# The standard way of fetching data from the collections is by using the find query if mongoDB. Using this we perform the fetching of data. Syntax of how to use this is found on the mongoDB official documentation.

# %% [markdown]
# __Solution 2a: Fetching climate data for 10th of December 2017__

# %%
#finding the record for the date match
for i in db.climateData.find({'date':'10/12/2017'}):
    print(i)
    print("\n\n")
# Out:
# {'_id': ObjectId('5cd8dfb43adc9af5ef087595'), 'station': 948702, 'date': '10/12/2017', 'air_temperature_celcius': 17, 'relative_humidity': 53.5, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'precipitation ': ' 0.00I'}

# %% [markdown]
# __ Solution 2b: Finding the latitude, longitude, surface temperature (°C), and confidence
# when the surface temperature (°C) was between 65 °C and 100 °C__

# %% [markdown]
# Using regular expressions in mongoDB we can fetch the data from the mongoDB database. Here we use __'\$gt'__ which fetches all the data with a higher value than specified and __'\$lt'__ which would fetch values lesser than specified value. Syntax of how to use regular expressions could be found in the mongoDB official documentation.

# %%
#now finding records satisfying the condition in the problem statement

for i in db.hotspot_historic.find({'surface_temperature_celcius': { "$gt": 65, "$lt":100  } },{'latitude':1, 'longitude':1,'surface_temperature_celcius':1,'confidence':1,'_id':0}):
    print(i)
    print("\n\n")
# Out:
# {'latitude': -37.966, 'longitude': 145.05100000000002, 'confidence': 78, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -35.543, 'longitude': 143.316, 'confidence': 86, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -37.875, 'longitude': 142.51, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.613, 'longitude': 149.305, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.624, 'longitude': 149.314, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -38.056999999999995, 'longitude': 144.211, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.95, 'longitude': 142.366, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.282, 'longitude': 146.157, 'confidence': 100, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.634, 'longitude': 149.237, 'confidence': 100, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.605, 'longitude': 149.30200000000002, 'confidence': 98, 'surface_temperature_celcius': 83}
#
#
#
# {'latitude': -37.6, 'longitude': 149.325, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -37.618, 'longitude': 149.281, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.606, 'longitude': 149.312, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -37.61, 'longitude': 149.30700000000002, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -37.609, 'longitude': 149.32, 'confidence': 99, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -37.945, 'longitude': 144.35399999999998, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.94, 'longitude': 143.281, 'confidence': 89, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -37.477, 'longitude': 143.352, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -37.475, 'longitude': 143.365, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.69, 'longitude': 143.605, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.098, 'longitude': 143.74, 'confidence': 92, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -37.247, 'longitude': 141.278, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.294000000000004, 'longitude': 141.232, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -37.293, 'longitude': 141.245, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -38.126999999999995, 'longitude': 143.82, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.461999999999996, 'longitude': 148.089, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.406, 'longitude': 148.123, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -37.452, 'longitude': 148.115, 'confidence': 68, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.45, 'longitude': 148.126, 'confidence': 64, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -37.436, 'longitude': 148.088, 'confidence': 86, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.444, 'longitude': 148.101, 'confidence': 73, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.562, 'longitude': 148.05, 'confidence': 61, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.379, 'longitude': 148.126, 'confidence': 58, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.379, 'longitude': 148.132, 'confidence': 62, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.399, 'longitude': 148.08100000000002, 'confidence': 100, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -37.400999999999996, 'longitude': 148.067, 'confidence': 100, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -37.4796, 'longitude': 141.9403, 'confidence': 94, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -37.8644, 'longitude': 143.4263, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.3774, 'longitude': 143.7079, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.3756, 'longitude': 143.7243, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -36.369, 'longitude': 143.7132, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.3799, 'longitude': 143.7149, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -36.2693, 'longitude': 143.1768, 'confidence': 94, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -36.1002, 'longitude': 142.3405, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.4325, 'longitude': 144.3142, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.7685, 'longitude': 142.7134, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.7801, 'longitude': 142.7151, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.7746, 'longitude': 146.6642, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.8359, 'longitude': 146.6448, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.9085, 'longitude': 141.1038, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -38.4349, 'longitude': 146.3122, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -37.9047, 'longitude': 141.0945, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.4984, 'longitude': 142.9739, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.253, 'longitude': 144.3681, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.9396, 'longitude': 143.1462, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.3387, 'longitude': 141.7542, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.3433, 'longitude': 143.4369, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -36.345, 'longitude': 143.4256, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -36.7032, 'longitude': 144.0992, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.3402, 'longitude': 141.7429, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.5023, 'longitude': 143.6038, 'confidence': 85, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.8616, 'longitude': 142.8025, 'confidence': 90, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -38.0372, 'longitude': 146.0616, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -38.049, 'longitude': 146.0513, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -36.0396, 'longitude': 141.7183, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.2775, 'longitude': 146.1026, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -38.0361, 'longitude': 146.0567, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -36.3254, 'longitude': 144.3638, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.0816, 'longitude': 145.859, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -36.1532, 'longitude': 143.5527, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -36.0077, 'longitude': 141.7747, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -36.0828, 'longitude': 145.873, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -36.5541, 'longitude': 144.1321, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -35.6819, 'longitude': 143.5275, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -35.6871, 'longitude': 143.5235, 'confidence': 90, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.1506, 'longitude': 143.5671, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -37.4671, 'longitude': 145.9962, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.2911, 'longitude': 141.1664, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.2842, 'longitude': 141.1741, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -37.3656, 'longitude': 141.3903, 'confidence': 84, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.4179, 'longitude': 144.2924, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -36.3207, 'longitude': 140.9737, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.2882, 'longitude': 141.1821, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -36.3153, 'longitude': 140.9789, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.4169, 'longitude': 144.2994, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -36.8094, 'longitude': 142.8885, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.8323, 'longitude': 147.2232, 'confidence': 84, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -38.2853, 'longitude': 145.9519, 'confidence': 98, 'surface_temperature_celcius': 83}
#
#
#
# {'latitude': -38.2375, 'longitude': 142.8363, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.4463, 'longitude': 142.7829, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.6854, 'longitude': 143.4543, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -38.0881, 'longitude': 143.9391, 'confidence': 99, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -38.0866, 'longitude': 143.9534, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -38.2391, 'longitude': 142.82, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -38.5123, 'longitude': 146.4007, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -36.3438, 'longitude': 141.5832, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.4357, 'longitude': 142.7813, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -37.5867, 'longitude': 143.6256, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -36.2306, 'longitude': 143.6408, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.4168, 'longitude': 141.6939, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.4211, 'longitude': 141.6875, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -35.6138, 'longitude': 143.8666, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.0885, 'longitude': 145.0359, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.3193, 'longitude': 145.9162, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.0652, 'longitude': 146.0764, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -36.0682, 'longitude': 146.0602, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.7889, 'longitude': 143.1324, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.6139, 'longitude': 143.501, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.9509, 'longitude': 143.9599, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.6224, 'longitude': 143.5092, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -38.0933, 'longitude': 143.9824, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.663000000000004, 'longitude': 142.8567, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.6982, 'longitude': 143.0549, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.7187, 'longitude': 143.805, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.7742, 'longitude': 145.1991, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -36.5061, 'longitude': 144.5675, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.4035, 'longitude': 140.9935, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -36.4286, 'longitude': 141.1567, 'confidence': 99, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.3635, 'longitude': 142.2809, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.664, 'longitude': 142.8802, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -36.6564, 'longitude': 142.8615, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.6657, 'longitude': 143.1675, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.8742, 'longitude': 142.7177, 'confidence': 98, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.7751, 'longitude': 145.1696, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.3961, 'longitude': 140.9781, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.7708, 'longitude': 145.1908, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.758, 'longitude': 143.179, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.7609, 'longitude': 143.1633, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -36.5116, 'longitude': 144.562, 'confidence': 89, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.803000000000004, 'longitude': 142.9261, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.7153, 'longitude': 143.8226, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -36.8791, 'longitude': 142.7261, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -36.7309, 'longitude': 142.3633, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -36.882, 'longitude': 142.7108, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.5135, 'longitude': 142.7238, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.2121, 'longitude': 144.6885, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -36.2206, 'longitude': 144.6856, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -38.0132, 'longitude': 146.5269, 'confidence': 88, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -38.0148, 'longitude': 146.5413, 'confidence': 87, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.8412, 'longitude': 147.2536, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -37.8429, 'longitude': 147.2691, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.5454, 'longitude': 144.7402, 'confidence': 100, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -36.7593, 'longitude': 142.895, 'confidence': 92, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.3435, 'longitude': 141.5513, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.6942, 'longitude': 143.8021, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.3459, 'longitude': 141.5586, 'confidence': 100, 'surface_temperature_celcius': 91}
#
#
#
# {'latitude': -36.4046, 'longitude': 141.1534, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.0594, 'longitude': 141.5907, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.0576, 'longitude': 141.6122, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -36.388000000000005, 'longitude': 141.8309, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.094, 'longitude': 145.7646, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.5438, 'longitude': 144.7548, 'confidence': 99, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.6537, 'longitude': 143.8781, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -38.1917, 'longitude': 147.0745, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -38.1987, 'longitude': 147.0666, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.9303, 'longitude': 143.1034, 'confidence': 70, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.3195, 'longitude': 146.0601, 'confidence': 83, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.5839, 'longitude': 143.0588, 'confidence': 100, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -36.5854, 'longitude': 143.0462, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -36.3014, 'longitude': 143.203, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.3332, 'longitude': 145.8594, 'confidence': 87, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.6775, 'longitude': 148.5131, 'confidence': 86, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.9111, 'longitude': 142.692, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.5115, 'longitude': 143.14, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -37.769, 'longitude': 147.94, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.1303, 'longitude': 146.3606, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.1345, 'longitude': 146.351, 'confidence': 98, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.1586, 'longitude': 145.6666, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -36.5847, 'longitude': 145.1968, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.1546, 'longitude': 141.8146, 'confidence': 88, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -37.9091, 'longitude': 143.5105, 'confidence': 87, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.1559, 'longitude': 141.8102, 'confidence': 80, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.9071, 'longitude': 143.53799999999998, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -37.3902, 'longitude': 148.2955, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.5027, 'longitude': 146.347, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -37.5043, 'longitude': 146.3299, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -36.1964, 'longitude': 144.5217, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.6397, 'longitude': 142.5968, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.6267, 'longitude': 142.9993, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.5871, 'longitude': 144.4958, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.6828, 'longitude': 144.784, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.4843, 'longitude': 143.0592, 'confidence': 89, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.7274, 'longitude': 142.9536, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.6964, 'longitude': 142.8583, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -38.0509, 'longitude': 143.9423, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.9284, 'longitude': 143.108, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.5701, 'longitude': 142.6497, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -36.7101, 'longitude': 142.3865, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -38.1693, 'longitude': 143.0466, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.7128, 'longitude': 142.3717, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.4885, 'longitude': 142.0658, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -36.7101, 'longitude': 142.981, 'confidence': 77, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.9594, 'longitude': 143.5638, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -36.5921, 'longitude': 144.4905, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -36.6787, 'longitude': 144.8042, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -38.0423, 'longitude': 146.4048, 'confidence': 84, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -38.1224, 'longitude': 143.7553, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -38.0792, 'longitude': 143.7361, 'confidence': 94, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -37.9157, 'longitude': 143.3544, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.7935, 'longitude': 143.1606, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.7756, 'longitude': 143.1388, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -37.7171, 'longitude': 142.9505, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.7236, 'longitude': 142.947, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.7002, 'longitude': 142.9562, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -37.6498, 'longitude': 142.5997, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.4352, 'longitude': 143.1444, 'confidence': 100, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -36.5828, 'longitude': 144.5775, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.5987, 'longitude': 144.4995, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.5262, 'longitude': 144.5737, 'confidence': 98, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.6995, 'longitude': 142.97799999999998, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.8879, 'longitude': 141.6647, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -35.8768, 'longitude': 145.4627, 'confidence': 100, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -36.4899, 'longitude': 142.2805, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.663000000000004, 'longitude': 141.3038, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.092, 'longitude': 141.7306, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -36.2637, 'longitude': 145.3649, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -37.2609, 'longitude': 141.7999, 'confidence': 89, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.91, 'longitude': 141.0704, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.2652, 'longitude': 145.3769, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.738, 'longitude': 142.1177, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.5199, 'longitude': 144.7311, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.0782, 'longitude': 145.3625, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.3966, 'longitude': 141.406, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -37.1349, 'longitude': 141.9491, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.7651, 'longitude': 143.5801, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.9329, 'longitude': 143.7796, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -35.8276, 'longitude': 143.7549, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -35.9326, 'longitude': 141.958, 'confidence': 78, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.6892, 'longitude': 145.2775, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.8283, 'longitude': 143.4605, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -36.6527, 'longitude': 142.7392, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -36.1898, 'longitude': 145.0922, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.8298, 'longitude': 143.4483, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.6615, 'longitude': 144.6014, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -36.8238, 'longitude': 143.5724, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.7499, 'longitude': 141.3006, 'confidence': 75, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -36.7432, 'longitude': 141.3296, 'confidence': 84, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.7531, 'longitude': 141.3253, 'confidence': 84, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.7943, 'longitude': 143.9571, 'confidence': 99, 'surface_temperature_celcius': 84}
#
#
#
# {'latitude': -36.7957, 'longitude': 143.9652, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -36.9498, 'longitude': 142.2012, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -36.1941, 'longitude': 143.1604, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.4142, 'longitude': 143.1077, 'confidence': 100, 'surface_temperature_celcius': 97}
#
#
#
# {'latitude': -36.1924, 'longitude': 143.1716, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.0761, 'longitude': 141.0574, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -35.0616, 'longitude': 141.4417, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.3999, 'longitude': 144.737, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -36.1748, 'longitude': 145.7582, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.0691, 'longitude': 145.7797, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -35.1949, 'longitude': 141.0622, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.91, 'longitude': 141.2705, 'confidence': 100, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -35.8071, 'longitude': 142.7318, 'confidence': 89, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.7787, 'longitude': 141.4449, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.2948, 'longitude': 141.3486, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.8185, 'longitude': 142.5609, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.1771, 'longitude': 145.7451, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -38.027, 'longitude': 142.3844, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -36.429, 'longitude': 141.5759, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.1346, 'longitude': 145.2196, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.0899, 'longitude': 141.0238, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -36.3823, 'longitude': 141.3146, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -36.1462, 'longitude': 145.2096, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.5243, 'longitude': 142.0839, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.618, 'longitude': 143.0013, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -36.8867, 'longitude': 142.1873, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.9364, 'longitude': 143.4996, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.3847, 'longitude': 142.8935, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -35.6374, 'longitude': 142.3787, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -36.8835, 'longitude': 142.2098, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.4125, 'longitude': 143.1189, 'confidence': 100, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -37.0669, 'longitude': 141.0556, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.0714, 'longitude': 145.7665, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.2933, 'longitude': 141.36, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.4591, 'longitude': 144.9492, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -36.3487, 'longitude': 145.5315, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.5399, 'longitude': 144.678, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.8158, 'longitude': 142.6229, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.4518, 'longitude': 144.7752, 'confidence': 100, 'surface_temperature_celcius': 97}
#
#
#
# {'latitude': -36.7903, 'longitude': 141.618, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.1067, 'longitude': 143.7948, 'confidence': 97, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.4816, 'longitude': 141.6635, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -36.0837, 'longitude': 144.2448, 'confidence': 100, 'surface_temperature_celcius': 87}
#
#
#
# {'latitude': -36.782, 'longitude': 141.8851, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.5586, 'longitude': 144.0423, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.5568, 'longitude': 144.0538, 'confidence': 90, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.4538, 'longitude': 144.763, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -36.4612, 'longitude': 144.7775, 'confidence': 91, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.7089, 'longitude': 143.3518, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -36.601, 'longitude': 144.6378, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.8681, 'longitude': 143.5186, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.1999, 'longitude': 143.8231, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.6171, 'longitude': 142.9426, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.7587, 'longitude': 142.8521, 'confidence': 84, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -37.4611, 'longitude': 144.9371, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -38.0254, 'longitude': 142.3959, 'confidence': 100, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -37.8885, 'longitude': 143.9157, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -35.0706, 'longitude': 141.4435, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -38.0795, 'longitude': 143.2449, 'confidence': 100, 'surface_temperature_celcius': 91}
#
#
#
# {'latitude': -35.1857, 'longitude': 141.0604, 'confidence': 100, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -35.6469, 'longitude': 142.376, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -35.6453, 'longitude': 142.387, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -36.4409, 'longitude': 141.6948, 'confidence': 100, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -37.9174, 'longitude': 145.8678, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -37.9152, 'longitude': 145.8808, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.8906, 'longitude': 146.2035, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -35.8182, 'longitude': 143.8739, 'confidence': 100, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -37.9246, 'longitude': 146.2464, 'confidence': 100, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -36.3313, 'longitude': 141.0017, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.2857, 'longitude': 141.3467, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.0749, 'longitude': 143.4058, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -36.4449, 'longitude': 140.9836, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.3972, 'longitude': 141.6041, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -36.5532, 'longitude': 142.5349, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.1367, 'longitude': 145.2071, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.1518, 'longitude': 144.0233, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.1418, 'longitude': 144.0261, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.5812, 'longitude': 142.7374, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.5949, 'longitude': 142.6857, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.8247, 'longitude': 143.6243, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.4028, 'longitude': 143.6932, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.4033, 'longitude': 143.6884, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.8249, 'longitude': 143.6174, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -36.6823, 'longitude': 142.5024, 'confidence': 93, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.4489, 'longitude': 144.7685, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.34, 'longitude': 149.3668, 'confidence': 67, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -36.7287, 'longitude': 142.6017, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -35.2363, 'longitude': 143.0004, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -35.2378, 'longitude': 142.9864, 'confidence': 100, 'surface_temperature_celcius': 94}
#
#
#
# {'latitude': -35.2381, 'longitude': 142.994, 'confidence': 98, 'surface_temperature_celcius': 83}
#
#
#
# {'latitude': -37.3493, 'longitude': 149.3691, 'confidence': 66, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.7165, 'longitude': 142.6155, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.2168, 'longitude': 147.4748, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -37.222, 'longitude': 147.4689, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.2063, 'longitude': 147.4713, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.2082, 'longitude': 147.4368, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.224000000000004, 'longitude': 147.4347, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.6334, 'longitude': 142.2244, 'confidence': 92, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -37.7966, 'longitude': 142.3196, 'confidence': 76, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -35.805, 'longitude': 142.1326, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -37.8429, 'longitude': 143.8366, 'confidence': 100, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -36.9918, 'longitude': 141.8667, 'confidence': 100, 'surface_temperature_celcius': 97}
#
#
#
# {'latitude': -36.1104, 'longitude': 145.9829, 'confidence': 90, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.782, 'longitude': 148.3844, 'confidence': 100, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -36.0157, 'longitude': 145.9414, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.777, 'longitude': 148.4128, 'confidence': 99, 'surface_temperature_celcius': 85}
#
#
#
# {'latitude': -37.5888, 'longitude': 148.5949, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.0844, 'longitude': 141.4934, 'confidence': 81, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.031, 'longitude': 145.6824, 'confidence': 91, 'surface_temperature_celcius': 69}
#
#
#
# {'latitude': -37.5814, 'longitude': 148.5777, 'confidence': 86, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.5788, 'longitude': 148.592, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.6384, 'longitude': 142.4075, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -35.811, 'longitude': 142.1403, 'confidence': 94, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -36.9034, 'longitude': 141.0013, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -37.803000000000004, 'longitude': 142.3151, 'confidence': 83, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.7542, 'longitude': 142.9949, 'confidence': 96, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.3803, 'longitude': 145.611, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.7617, 'longitude': 143.08100000000002, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -37.8161, 'longitude': 142.9286, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.0387, 'longitude': 145.6787, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.6349, 'longitude': 142.2125, 'confidence': 94, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -36.6986, 'longitude': 142.7259, 'confidence': 86, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -38.0052, 'longitude': 142.6179, 'confidence': 94, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87, 'surface_temperature_celcius': 88}
#
#
#
# {'latitude': -37.6439, 'longitude': 142.91299999999998, 'confidence': 93, 'surface_temperature_celcius': 83}
#
#
#
# {'latitude': -37.3165, 'longitude': 147.4932, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.3158, 'longitude': 147.4986, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.7835, 'longitude': 148.4138, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.4323, 'longitude': 147.6583, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.4343, 'longitude': 147.6327, 'confidence': 100, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -35.4033, 'longitude': 143.267, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.6281, 'longitude': 142.4349, 'confidence': 64, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.111, 'longitude': 145.124, 'confidence': 85, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.1615, 'longitude': 141.8728, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.1122, 'longitude': 142.1491, 'confidence': 90, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -37.3735, 'longitude': 145.8384, 'confidence': 100, 'surface_temperature_celcius': 95}
#
#
#
# {'latitude': -36.1955, 'longitude': 145.914, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -35.4533, 'longitude': 143.2029, 'confidence': 85, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -36.5989, 'longitude': 141.9771, 'confidence': 92, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -36.6299, 'longitude': 142.4234, 'confidence': 66, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.1925, 'longitude': 145.93, 'confidence': 97, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -36.095, 'longitude': 141.7699, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -36.6006, 'longitude': 141.9657, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.0769, 'longitude': 141.042, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.883, 'longitude': 142.1637, 'confidence': 79, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -36.0973, 'longitude': 143.4279, 'confidence': 87, 'surface_temperature_celcius': 92}
#
#
#
# {'latitude': -36.1819, 'longitude': 145.9269, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.3735, 'longitude': 145.886, 'confidence': 87, 'surface_temperature_celcius': 96}
#
#
#
# {'latitude': -37.7465, 'longitude': 143.3806, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -37.8072, 'longitude': 145.9738, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.3704, 'longitude': 145.8942, 'confidence': 96, 'surface_temperature_celcius': 78}
#
#
#
# {'latitude': -37.297, 'longitude': 143.5753, 'confidence': 100, 'surface_temperature_celcius': 93}
#
#
#
# {'latitude': -37.2988, 'longitude': 143.5487, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.3025, 'longitude': 143.5714, 'confidence': 100, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.383, 'longitude': 145.9089, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -37.7446, 'longitude': 143.4085, 'confidence': 89, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.7509, 'longitude': 143.4023, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.7974, 'longitude': 145.9535, 'confidence': 87, 'surface_temperature_celcius': 97}
#
#
#
# {'latitude': -35.7657, 'longitude': 142.0906, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.7236, 'longitude': 143.3995, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -37.3046, 'longitude': 143.5448, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.4312, 'longitude': 141.2064, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.4557, 'longitude': 142.2434, 'confidence': 92, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -36.8009, 'longitude': 142.7259, 'confidence': 95, 'surface_temperature_celcius': 76}
#
#
#
# {'latitude': -36.8099, 'longitude': 142.72799999999998, 'confidence': 93, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -36.7806, 'longitude': 141.5597, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -34.3526, 'longitude': 141.6458, 'confidence': 98, 'surface_temperature_celcius': 82}
#
#
#
# {'latitude': -37.0924, 'longitude': 141.89700000000002, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -37.9452, 'longitude': 143.5834, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -34.351, 'longitude': 141.6567, 'confidence': 99, 'surface_temperature_celcius': 86}
#
#
#
# {'latitude': -37.5012, 'longitude': 142.5853, 'confidence': 100, 'surface_temperature_celcius': 90}
#
#
#
# {'latitude': -37.9247, 'longitude': 142.8999, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -35.0805, 'longitude': 142.4642, 'confidence': 97, 'surface_temperature_celcius': 81}
#
#
#
# {'latitude': -37.522, 'longitude': 143.3874, 'confidence': 71, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -38.0674, 'longitude': 142.965, 'confidence': 91, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -38.0715, 'longitude': 142.9591, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -38.0693, 'longitude': 142.9722, 'confidence': 100, 'surface_temperature_celcius': 89}
#
#
#
# {'latitude': -37.7805, 'longitude': 143.5003, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.8774, 'longitude': 145.8213, 'confidence': 95, 'surface_temperature_celcius': 77}
#
#
#
# {'latitude': -37.8881, 'longitude': 145.8229, 'confidence': 100, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -37.6622, 'longitude': 142.1001, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -37.4523, 'longitude': 147.0175, 'confidence': 90, 'surface_temperature_celcius': 66}
#
#
#
# {'latitude': -37.4261, 'longitude': 147.0323, 'confidence': 98, 'surface_temperature_celcius': 83}
#
#
#
# {'latitude': -37.3949, 'longitude': 147.0175, 'confidence': 100, 'surface_temperature_celcius': 91}
#
#
#
# {'latitude': -37.6625, 'longitude': 144.287, 'confidence': 92, 'surface_temperature_celcius': 70}
#
#
#
# {'latitude': -37.0155, 'longitude': 148.1432, 'confidence': 97, 'surface_temperature_celcius': 80}
#
#
#
# {'latitude': -36.7152, 'longitude': 141.3853, 'confidence': 94, 'surface_temperature_celcius': 74}
#
#
#
# {'latitude': -34.357, 'longitude': 141.5361, 'confidence': 90, 'surface_temperature_celcius': 67}
#
#
#
# {'latitude': -34.3539, 'longitude': 141.5547, 'confidence': 93, 'surface_temperature_celcius': 72}
#
#
#
# {'latitude': -36.9939, 'longitude': 148.2244, 'confidence': 90, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -36.9959, 'longitude': 148.2118, 'confidence': 95, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -34.3554, 'longitude': 141.5413, 'confidence': 96, 'surface_temperature_celcius': 79}
#
#
#
# {'latitude': -34.3555, 'longitude': 141.5495, 'confidence': 94, 'surface_temperature_celcius': 75}
#
#
#
# {'latitude': -37.0193, 'longitude': 148.1459, 'confidence': 84, 'surface_temperature_celcius': 71}
#
#
#
# {'latitude': -37.4229, 'longitude': 147.02700000000002, 'confidence': 100, 'surface_temperature_celcius': 99}
#
#
#
# {'latitude': -37.0055, 'longitude': 148.1582, 'confidence': 80, 'surface_temperature_celcius': 68}
#
#
#
# {'latitude': -37.4128, 'longitude': 147.0242, 'confidence': 85, 'surface_temperature_celcius': 98}
#
#
#
# {'latitude': -37.2284, 'longitude': 147.9187, 'confidence': 94, 'surface_temperature_celcius': 73}
#
#
#
# {'latitude': -37.6572, 'longitude': 142.0703, 'confidence': 97, 'surface_temperature_celcius': 80}

# %% [markdown]
# __Solution 2c: Finding date, surface temperature (°C), air temperature (°C), relative humidity and
# max wind speed on 15th and 16th of December 2017.__

# %% [markdown]
# Now lies a slightly difficult task in this question. Here we have to fetch data from two different collections. The collections named climateData would have 'air temperature', 'relative humidity' and 'max wind speed' and the collection hotspot_historic has 'surface temperature'.

# %%
print("total number of unique dates", len(df_climate_historic['date'].unique()))
print("total number of unique records",len(df_climate_historic))
# Out:
# total number of unique dates 366
# total number of unique records 366

# %% [markdown]
# For overcomming this problem a small trick has been used here. If observed 'date' is a common tag in both the data and in the climateData collection for one date there is only one record which can be seen in the above output. Hence a list is used for storing hotspot_historic and climateData records and then based on date they are sorted. After the sorting is done they are merged based on date and then displayed.

# %% [markdown]
# The first step thus is to fetch data for the dates 15 and 16 December 2017 from both the collections

# %%
# for finding the date and surface temperature based on the date
hotspot_list = []
climate_list = []
for i in db.hotspot_historic.find( {'$or': [{'date': '15/12/2017'},{'date': '16/12/2017'}]},{'date':1, '_id':0, 'surface_temperature_celcius':1}):
    hotspot_list.append(i)
    
# for finding the air tempurature relative humidity and max wind speed based on the date 
for i in db.climateData.find({'$or':[{'date':'15/12/2017'},{'date':'16/12/2017'}]},{'_id':0, 'air_temperature_celcius':1, 'relative_humidity':1, 'max_wind_speed':1, 'date':1}):
    climate_list.append(i)

# %% [markdown]
# Now that we have fetched the data and stored it in the list we would merge the list based on the date tag

# %%
hotspot_list_sort = sorted(hotspot_list, key = lambda i: i['date'])
climate_list_sort = sorted(climate_list, key = lambda i: i['date'])
hotspotindex = 0
for i in climate_list_sort:
    dateval = i['date']
    air_temp = i['air_temperature_celcius']
    for j in range(hotspotindex,len(hotspot_list_sort)):
        if(hotspot_list_sort[j]['date'] == dateval):
            hotspot_list_sort[j].update(i)
for i in hotspot_list_sort:
    print(i)
# Out:
# {'date': '15/12/2017', 'surface_temperature_celcius': 42, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0}
# {'date': '15/12/2017', 'surface_temperature_celcius': 36, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0}
# {'date': '15/12/2017', 'surface_temperature_celcius': 38, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0}
# {'date': '15/12/2017', 'surface_temperature_celcius': 40, 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 43, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 33, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 48, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}
# {'date': '16/12/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0}

# %% [markdown]
# __Solution 2d: Finding datetime, air temperature (°C), surface temperature (°C) and confidence
# when the confidence is between 80 and 100.__

# %% [markdown]
# This question is very similar to the last question where we fetch data from different collections.

# %% [markdown]
# Hence in this solution too the same procedure is followed where in we fetch the data from the collections and store it in different list. Then we would sort the lists based on date and merge the lists.

# %% [markdown]
# __Some points to note in this solution are:__
# * As we see that in the climate_historic.csv file we have the air temperature and date columns
# * Also in the hotspot_historic.csv we have the confidence and date columns
# * Hence for finding the solution we have to find the dates for the cvonfidence intervals and then find unique dates of them
# * In the climate_historic.csv we can see that there is records which is unique for the dates
# * Hence for the unique dates we would fetch the records and then display the air temperature
# * Regular expressions are used for fetching the data, syntax and use or regular expressions can be found in mongoDB official docs.

# %%
lisun=[] #creating a list to store all the date values for confidence intervals between 80 and 100

hotspot_historic = []
climate_data = []

#appending the date values from hotspot_historic.csv file based on the conofidence interval range
for i in db.hotspot_historic.find({'confidence': {'$gt': 80, '$lt':100}},{'_id':0, 'datetime':1, 'surface_temperature_celcius':1, 'date':1, 'confidence':1}):
    if i['date'] not in lisun:
        lisun.append(i['date'])
    hotspot_historic.append(i) #print of datetime, confidence, date and surface temperature based on the confidence interval range
    
print("\n\n")


#print of date and air temperature for the specific confidence interval range
for i in db.climateData.find({'date': {'$in': lisun}}, {'_id':0, 'air_temperature_celcius':1, 'date':1}):
    climate_data.append(i)

# %% [markdown]
# Now that we have fetched the data and stored it in different lists we would sort the lists based on date and then merge them based on date itself.

# %%
hotspot_historic_sorted = sorted(hotspot_historic, key = lambda i: i['date'])
climate_data_sorted = sorted(climate_data, key = lambda i: i['date'])
hotspotindex = 0
for i in climate_data_sorted:
    dateval = i['date']
    air_temp = i['air_temperature_celcius']
    for j in range(hotspotindex,len(hotspot_historic_sorted)):
        if(hotspot_historic_sorted[j]['date'] == dateval):
            hotspot_historic_sorted[j].update(i)
for i in hotspot_historic_sorted:
    print(i)
# Out:
# {'datetime': '2017-05-01T04:17:50', 'confidence': 94, 'date': '1/05/2017', 'surface_temperature_celcius': 103, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:30', 'confidence': 82, 'date': '1/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:30', 'confidence': 82, 'date': '1/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:20', 'confidence': 83, 'date': '1/05/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:20', 'confidence': 82, 'date': '1/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:20', 'confidence': 95, 'date': '1/05/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:20', 'confidence': 85, 'date': '1/05/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-01T04:14:20', 'confidence': 87, 'date': '1/05/2017', 'surface_temperature_celcius': 117, 'air_temperature_celcius': 14}
# {'datetime': '2017-06-01T05:09:20', 'confidence': 82, 'date': '1/06/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 11}
# {'datetime': '2017-08-01T00:20:30', 'confidence': 89, 'date': '1/08/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 7}
# {'datetime': '2017-10-01T04:10:28', 'confidence': 84, 'date': '1/10/2017', 'surface_temperature_celcius': 52, 'air_temperature_celcius': 12}
# {'datetime': '2017-10-01T04:10:28', 'confidence': 89, 'date': '1/10/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 12}
# {'datetime': '2017-03-10T04:45:30', 'confidence': 94, 'date': '10/03/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 19}
# {'datetime': '2017-03-10T04:45:30', 'confidence': 97, 'date': '10/03/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 19}
# {'datetime': '2017-03-10T04:43:50', 'confidence': 81, 'date': '10/03/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 19}
# {'datetime': '2017-05-10T04:16:30', 'confidence': 96, 'date': '10/05/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:16:10', 'confidence': 84, 'date': '10/05/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:14:20', 'confidence': 88, 'date': '10/05/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:12:50', 'confidence': 87, 'date': '10/05/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:12:50', 'confidence': 86, 'date': '10/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:11:30', 'confidence': 83, 'date': '10/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:11:10', 'confidence': 84, 'date': '10/05/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:11:10', 'confidence': 81, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:50', 'confidence': 82, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:50', 'confidence': 98, 'date': '10/05/2017', 'surface_temperature_celcius': 83, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:50', 'confidence': 98, 'date': '10/05/2017', 'surface_temperature_celcius': 82, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:50', 'confidence': 82, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:50', 'confidence': 92, 'date': '10/05/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:30', 'confidence': 84, 'date': '10/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:30', 'confidence': 86, 'date': '10/05/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:30', 'confidence': 83, 'date': '10/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 95, 'date': '10/05/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 85, 'date': '10/05/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 99, 'date': '10/05/2017', 'surface_temperature_celcius': 84, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 96, 'date': '10/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 92, 'date': '10/05/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 81, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 86, 'date': '10/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 81, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 87, 'date': '10/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 84, 'date': '10/05/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 81, 'date': '10/05/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 96, 'date': '10/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 87, 'date': '10/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 86, 'date': '10/05/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 94, 'date': '10/05/2017', 'surface_temperature_celcius': 74, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 82, 'date': '10/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 87, 'date': '10/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 85, 'date': '10/05/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-10T04:08:10', 'confidence': 99, 'date': '10/05/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 10}
# {'datetime': '2017-09-10T03:53:00', 'confidence': 84, 'date': '10/09/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 11}
# {'datetime': '2017-09-10T03:50:30', 'confidence': 86, 'date': '10/09/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 11}
# {'datetime': '2017-09-10T03:50:10', 'confidence': 81, 'date': '10/09/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 11}
# {'datetime': '2017-10-10T04:04:19', 'confidence': 96, 'date': '10/10/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-11T04:39:20', 'confidence': 81, 'date': '11/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-11T04:39:00', 'confidence': 84, 'date': '11/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-11T04:39:00', 'confidence': 85, 'date': '11/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-11T04:57:20', 'confidence': 90, 'date': '11/05/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:57:20', 'confidence': 96, 'date': '11/05/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:54:00', 'confidence': 88, 'date': '11/05/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:51:00', 'confidence': 89, 'date': '11/05/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 84, 'date': '11/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 94, 'date': '11/05/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 92, 'date': '11/05/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 99, 'date': '11/05/2017', 'surface_temperature_celcius': 86, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 91, 'date': '11/05/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-11T04:50:40', 'confidence': 97, 'date': '11/05/2017', 'surface_temperature_celcius': 81, 'air_temperature_celcius': 9}
# {'datetime': '2017-11-11T04:04:25', 'confidence': 86, 'date': '11/11/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 18}
# {'datetime': '2017-03-12T04:33:50', 'confidence': 94, 'date': '12/03/2017', 'surface_temperature_celcius': 105, 'air_temperature_celcius': 21}
# {'datetime': '2017-03-12T04:29:50', 'confidence': 84, 'date': '12/03/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 21}
# {'datetime': '2017-03-12T04:27:20', 'confidence': 85, 'date': '12/03/2017', 'surface_temperature_celcius': 98, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-12T13:15:10', 'confidence': 93, 'date': '12/04/2017', 'surface_temperature_celcius': 43, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T05:28:00', 'confidence': 84, 'date': '12/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T05:21:40', 'confidence': 94, 'date': '12/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:54:10', 'confidence': 95, 'date': '12/04/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:50:00', 'confidence': 87, 'date': '12/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:50:00', 'confidence': 95, 'date': '12/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:50:00', 'confidence': 86, 'date': '12/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:47:50', 'confidence': 92, 'date': '12/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:47:50', 'confidence': 84, 'date': '12/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:47:30', 'confidence': 84, 'date': '12/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:47:20', 'confidence': 83, 'date': '12/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:47:20', 'confidence': 84, 'date': '12/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:45:10', 'confidence': 85, 'date': '12/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:44:40', 'confidence': 87, 'date': '12/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:44:40', 'confidence': 93, 'date': '12/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:44:40', 'confidence': 82, 'date': '12/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 14}
# {'datetime': '2017-04-12T03:44:40', 'confidence': 93, 'date': '12/04/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-12T03:57:40', 'confidence': 83, 'date': '12/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-12T03:56:10', 'confidence': 93, 'date': '12/05/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-12T03:56:10', 'confidence': 87, 'date': '12/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 14}
# {'datetime': '2017-11-12T00:33:15', 'confidence': 89, 'date': '12/11/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 18}
# {'datetime': '2017-04-13T04:38:00', 'confidence': 96, 'date': '13/04/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:38:00', 'confidence': 93, 'date': '13/04/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:36:50', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:36:30', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:36:20', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:35:40', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:35:40', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:35:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:34:40', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:34:20', 'confidence': 93, 'date': '13/04/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:40', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:40', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:30', 'confidence': 99, 'date': '13/04/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:30', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:20', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:10', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:00', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:33:00', 'confidence': 82, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:31:00', 'confidence': 98, 'date': '13/04/2017', 'surface_temperature_celcius': 82, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:30:50', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:30:50', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:30:10', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:30:00', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:29:50', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:29:40', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:29:40', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:50', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:20', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:20', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 93, 'date': '13/04/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:28:10', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:40', 'confidence': 98, 'date': '13/04/2017', 'surface_temperature_celcius': 82, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:40', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:30', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:27:20', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:50', 'confidence': 94, 'date': '13/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:50', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:50', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:50', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:40', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 94, 'date': '13/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 81, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 87, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 97, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 82, 'date': '13/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 85, 'date': '13/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 89, 'date': '13/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 99, 'date': '13/04/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 84, 'date': '13/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 86, 'date': '13/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 94, 'date': '13/04/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 87, 'date': '13/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 83, 'date': '13/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 88, 'date': '13/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 91, 'date': '13/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 81, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 82, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 90, 'date': '13/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T04:26:30', 'confidence': 92, 'date': '13/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T00:07:40', 'confidence': 82, 'date': '13/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T00:07:10', 'confidence': 96, 'date': '13/04/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 16}
# {'datetime': '2017-04-13T00:07:00', 'confidence': 95, 'date': '13/04/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 16}
# {'datetime': '2017-05-13T04:43:30', 'confidence': 95, 'date': '13/05/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:39:50', 'confidence': 81, 'date': '13/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:39:30', 'confidence': 83, 'date': '13/05/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:39:00', 'confidence': 85, 'date': '13/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 87, 'date': '13/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 81, 'date': '13/05/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 86, 'date': '13/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 84, 'date': '13/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 85, 'date': '13/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 87, 'date': '13/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 84, 'date': '13/05/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 94, 'date': '13/05/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 82, 'date': '13/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 91, 'date': '13/05/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 91, 'date': '13/05/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 82, 'date': '13/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 90, 'date': '13/05/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 86, 'date': '13/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 9}
# {'datetime': '2017-05-13T04:38:40', 'confidence': 85, 'date': '13/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 9}
# {'datetime': '2017-08-13T05:08:00', 'confidence': 87, 'date': '13/08/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 15}
# {'datetime': '2017-08-13T05:02:30', 'confidence': 83, 'date': '13/08/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 15}
# {'datetime': '2017-11-13T03:52:15', 'confidence': 87, 'date': '13/11/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 24}
# {'datetime': '2017-11-13T03:52:14', 'confidence': 81, 'date': '13/11/2017', 'surface_temperature_celcius': 53, 'air_temperature_celcius': 24}
# {'datetime': '2017-12-13T04:04:19', 'confidence': 83, 'date': '13/12/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 28}
# {'datetime': '2017-03-14T04:24:40', 'confidence': 90, 'date': '14/03/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:22:20', 'confidence': 93, 'date': '14/03/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:20:50', 'confidence': 90, 'date': '14/03/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:16:30', 'confidence': 95, 'date': '14/03/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:16:20', 'confidence': 89, 'date': '14/03/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:14:40', 'confidence': 81, 'date': '14/03/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:14:30', 'confidence': 96, 'date': '14/03/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 25}
# {'datetime': '2017-03-14T04:14:30', 'confidence': 94, 'date': '14/03/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 25}
# {'datetime': '2017-04-14T05:15:50', 'confidence': 82, 'date': '14/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T05:09:10', 'confidence': 87, 'date': '14/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T05:09:10', 'confidence': 84, 'date': '14/04/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T05:09:10', 'confidence': 84, 'date': '14/04/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T03:35:20', 'confidence': 86, 'date': '14/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T03:33:00', 'confidence': 99, 'date': '14/04/2017', 'surface_temperature_celcius': 84, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-14T03:33:00', 'confidence': 87, 'date': '14/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 13}
# {'datetime': '2017-06-14T04:43:00', 'confidence': 94, 'date': '14/06/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 11}
# {'datetime': '2017-11-14T04:35:04', 'confidence': 87, 'date': '14/11/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 28}
# {'datetime': '2017-12-14T04:47:25', 'confidence': 92, 'date': '14/12/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 17}
# {'datetime': '2017-04-15T04:20:40', 'confidence': 98, 'date': '15/04/2017', 'surface_temperature_celcius': 82, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:20:40', 'confidence': 99, 'date': '15/04/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:17:30', 'confidence': 87, 'date': '15/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:17:10', 'confidence': 94, 'date': '15/04/2017', 'surface_temperature_celcius': 113, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:16:00', 'confidence': 81, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:16:00', 'confidence': 82, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:40', 'confidence': 82, 'date': '15/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 82, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 88, 'date': '15/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 84, 'date': '15/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 86, 'date': '15/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 91, 'date': '15/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:10', 'confidence': 89, 'date': '15/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:15:00', 'confidence': 81, 'date': '15/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:50', 'confidence': 81, 'date': '15/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:50', 'confidence': 97, 'date': '15/04/2017', 'surface_temperature_celcius': 81, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:50', 'confidence': 96, 'date': '15/04/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 96, 'date': '15/04/2017', 'surface_temperature_celcius': 79, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 81, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 93, 'date': '15/04/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 82, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 87, 'date': '15/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 12}
# {'datetime': '2017-04-15T04:14:20', 'confidence': 82, 'date': '15/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-15T04:34:30', 'confidence': 93, 'date': '15/05/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:34:30', 'confidence': 96, 'date': '15/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:33:00', 'confidence': 83, 'date': '15/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:33:00', 'confidence': 92, 'date': '15/05/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:32:50', 'confidence': 84, 'date': '15/05/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:31:20', 'confidence': 96, 'date': '15/05/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:31:10', 'confidence': 87, 'date': '15/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:30:00', 'confidence': 86, 'date': '15/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:29:50', 'confidence': 83, 'date': '15/05/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:29:50', 'confidence': 84, 'date': '15/05/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:28:00', 'confidence': 87, 'date': '15/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:27:50', 'confidence': 90, 'date': '15/05/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 84, 'date': '15/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 96, 'date': '15/05/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 89, 'date': '15/05/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 83, 'date': '15/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 82, 'date': '15/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 85, 'date': '15/05/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 90, 'date': '15/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 86, 'date': '15/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 82, 'date': '15/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 83, 'date': '15/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 86, 'date': '15/05/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 90, 'date': '15/05/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 94, 'date': '15/05/2017', 'surface_temperature_celcius': 74, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 89, 'date': '15/05/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 95, 'date': '15/05/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 81, 'date': '15/05/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 94, 'date': '15/05/2017', 'surface_temperature_celcius': 74, 'air_temperature_celcius': 10}
# {'datetime': '2017-05-15T04:26:20', 'confidence': 86, 'date': '15/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 10}
# {'datetime': '2017-10-15T04:23:01', 'confidence': 99, 'date': '15/10/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 13}
# {'datetime': '2017-12-15T13:17:17', 'confidence': 92, 'date': '15/12/2017', 'surface_temperature_celcius': 42, 'air_temperature_celcius': 18}
# {'datetime': '2017-04-16T05:07:40', 'confidence': 83, 'date': '16/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 15}
# {'datetime': '2017-04-16T04:59:30', 'confidence': 87, 'date': '16/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 15}
# {'datetime': '2017-04-16T04:56:50', 'confidence': 83, 'date': '16/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 15}
# {'datetime': '2017-04-16T04:56:50', 'confidence': 91, 'date': '16/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 15}
# {'datetime': '2017-04-16T04:56:50', 'confidence': 86, 'date': '16/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 15}
# {'datetime': '2017-12-16T15:38:39', 'confidence': 94, 'date': '16/12/2017', 'surface_temperature_celcius': 43, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T04:35:13', 'confidence': 93, 'date': '16/12/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T04:34:58', 'confidence': 84, 'date': '16/12/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T04:34:58', 'confidence': 95, 'date': '16/12/2017', 'surface_temperature_celcius': 75, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T04:34:57', 'confidence': 90, 'date': '16/12/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T00:21:12', 'confidence': 93, 'date': '16/12/2017', 'surface_temperature_celcius': 73, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T00:21:11', 'confidence': 82, 'date': '16/12/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 18}
# {'datetime': '2017-12-16T00:20:53', 'confidence': 82, 'date': '16/12/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 18}
# {'datetime': '2017-03-17T04:48:20', 'confidence': 94, 'date': '17/03/2017', 'surface_temperature_celcius': 74, 'air_temperature_celcius': 18}
# {'datetime': '2017-03-17T04:45:10', 'confidence': 84, 'date': '17/03/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 18}
# {'datetime': '2017-03-17T04:45:00', 'confidence': 86, 'date': '17/03/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 18}
# {'datetime': '2017-04-17T04:08:20', 'confidence': 81, 'date': '17/04/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-17T04:03:50', 'confidence': 83, 'date': '17/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-17T04:03:10', 'confidence': 82, 'date': '17/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-17T04:02:40', 'confidence': 81, 'date': '17/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-17T04:02:20', 'confidence': 95, 'date': '17/04/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 13}
# {'datetime': '2017-04-17T04:02:20', 'confidence': 87, 'date': '17/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 13}
# ...
# {'datetime': '2017-05-05T03:53:20', 'confidence': 87, 'date': '5/05/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:53:10', 'confidence': 84, 'date': '5/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:53:10', 'confidence': 95, 'date': '5/05/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:51:50', 'confidence': 82, 'date': '5/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:50:20', 'confidence': 82, 'date': '5/05/2017', 'surface_temperature_celcius': 55, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:50:20', 'confidence': 82, 'date': '5/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:50:20', 'confidence': 97, 'date': '5/05/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 14}
# {'datetime': '2017-05-05T03:50:20', 'confidence': 96, 'date': '5/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 14}
# {'datetime': '2017-11-05T04:41:34', 'confidence': 83, 'date': '5/11/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 13}
# {'datetime': '2017-11-05T04:41:19', 'confidence': 90, 'date': '5/11/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 13}
# {'datetime': '2017-11-05T04:41:19', 'confidence': 89, 'date': '5/11/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 13}
# {'datetime': '2017-03-06T05:06:30', 'confidence': 87, 'date': '6/03/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 20}
# {'datetime': '2017-03-06T05:06:20', 'confidence': 85, 'date': '6/03/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 20}
# {'datetime': '2017-04-06T13:45:30', 'confidence': 97, 'date': '6/04/2017', 'surface_temperature_celcius': 45, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:32:20', 'confidence': 84, 'date': '6/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:31:10', 'confidence': 92, 'date': '6/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:27:10', 'confidence': 81, 'date': '6/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:27:00', 'confidence': 86, 'date': '6/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:27:00', 'confidence': 90, 'date': '6/04/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:27:00', 'confidence': 83, 'date': '6/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:24:40', 'confidence': 83, 'date': '6/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:24:20', 'confidence': 89, 'date': '6/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:24:20', 'confidence': 89, 'date': '6/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:24:00', 'confidence': 89, 'date': '6/04/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:23:50', 'confidence': 92, 'date': '6/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:23:50', 'confidence': 99, 'date': '6/04/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:23:30', 'confidence': 93, 'date': '6/04/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:23:10', 'confidence': 89, 'date': '6/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:23:00', 'confidence': 87, 'date': '6/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:40', 'confidence': 85, 'date': '6/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:20', 'confidence': 83, 'date': '6/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:20', 'confidence': 81, 'date': '6/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:20', 'confidence': 85, 'date': '6/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:20', 'confidence': 91, 'date': '6/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:10', 'confidence': 86, 'date': '6/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:10', 'confidence': 85, 'date': '6/04/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:22:10', 'confidence': 90, 'date': '6/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:21:30', 'confidence': 90, 'date': '6/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:21:10', 'confidence': 94, 'date': '6/04/2017', 'surface_temperature_celcius': 96, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:21:00', 'confidence': 84, 'date': '6/04/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:50', 'confidence': 88, 'date': '6/04/2017', 'surface_temperature_celcius': 65, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:50', 'confidence': 83, 'date': '6/04/2017', 'surface_temperature_celcius': 63, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 81, 'date': '6/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 83, 'date': '6/04/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 96, 'date': '6/04/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 91, 'date': '6/04/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 97, 'date': '6/04/2017', 'surface_temperature_celcius': 81, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 82, 'date': '6/04/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 94, 'date': '6/04/2017', 'surface_temperature_celcius': 104, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 92, 'date': '6/04/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 87, 'date': '6/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 81, 'date': '6/04/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 85, 'date': '6/04/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 90, 'date': '6/04/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 87, 'date': '6/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 94, 'date': '6/04/2017', 'surface_temperature_celcius': 86, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 84, 'date': '6/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 87, 'date': '6/04/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 86, 'date': '6/04/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 81, 'date': '6/04/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-06T04:20:40', 'confidence': 94, 'date': '6/04/2017', 'surface_temperature_celcius': 89, 'air_temperature_celcius': 19}
# {'datetime': '2017-05-06T04:39:00', 'confidence': 91, 'date': '6/05/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T04:33:00', 'confidence': 95, 'date': '6/05/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T04:32:50', 'confidence': 96, 'date': '6/05/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T04:32:30', 'confidence': 85, 'date': '6/05/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T04:32:20', 'confidence': 98, 'date': '6/05/2017', 'surface_temperature_celcius': 82, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T00:16:40', 'confidence': 83, 'date': '6/05/2017', 'surface_temperature_celcius': 57, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-06T00:13:50', 'confidence': 92, 'date': '6/05/2017', 'surface_temperature_celcius': 71, 'air_temperature_celcius': 12}
# {'datetime': '2017-07-06T04:08:00', 'confidence': 83, 'date': '6/07/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 9}
# {'datetime': '2017-07-06T04:02:00', 'confidence': 91, 'date': '6/07/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 9}
# {'datetime': '2017-03-07T04:16:10', 'confidence': 88, 'date': '7/03/2017', 'surface_temperature_celcius': 64, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-07T12:56:50', 'confidence': 85, 'date': '7/04/2017', 'surface_temperature_celcius': 41, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:56:30', 'confidence': 94, 'date': '7/04/2017', 'surface_temperature_celcius': 49, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:53:40', 'confidence': 86, 'date': '7/04/2017', 'surface_temperature_celcius': 41, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:52:10', 'confidence': 86, 'date': '7/04/2017', 'surface_temperature_celcius': 41, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:51:20', 'confidence': 97, 'date': '7/04/2017', 'surface_temperature_celcius': 45, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:50:50', 'confidence': 92, 'date': '7/04/2017', 'surface_temperature_celcius': 43, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T12:50:40', 'confidence': 89, 'date': '7/04/2017', 'surface_temperature_celcius': 42, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T05:03:10', 'confidence': 81, 'date': '7/04/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T03:28:20', 'confidence': 96, 'date': '7/04/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T03:27:30', 'confidence': 92, 'date': '7/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T03:27:20', 'confidence': 92, 'date': '7/04/2017', 'surface_temperature_celcius': 70, 'air_temperature_celcius': 21}
# {'datetime': '2017-04-07T03:27:20', 'confidence': 95, 'date': '7/04/2017', 'surface_temperature_celcius': 76, 'air_temperature_celcius': 21}
# {'datetime': '2017-06-07T04:35:50', 'confidence': 86, 'date': '7/06/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 8}
# {'datetime': '2017-06-07T04:33:50', 'confidence': 96, 'date': '7/06/2017', 'surface_temperature_celcius': 78, 'air_temperature_celcius': 8}
# {'datetime': '2017-06-07T04:32:10', 'confidence': 85, 'date': '7/06/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 8}
# {'datetime': '2017-06-07T04:32:10', 'confidence': 81, 'date': '7/06/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 8}
# {'datetime': '2017-06-07T04:32:10', 'confidence': 85, 'date': '7/06/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 8}
# {'datetime': '2017-06-07T04:32:10', 'confidence': 90, 'date': '7/06/2017', 'surface_temperature_celcius': 67, 'air_temperature_celcius': 8}
# {'datetime': '2017-10-07T12:59:33', 'confidence': 91, 'date': '7/10/2017', 'surface_temperature_celcius': 42, 'air_temperature_celcius': 17}
# {'datetime': '2017-04-08T04:14:00', 'confidence': 99, 'date': '8/04/2017', 'surface_temperature_celcius': 85, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-08T04:12:50', 'confidence': 91, 'date': '8/04/2017', 'surface_temperature_celcius': 69, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-08T04:08:50', 'confidence': 98, 'date': '8/04/2017', 'surface_temperature_celcius': 83, 'air_temperature_celcius': 19}
# {'datetime': '2017-04-08T04:08:30', 'confidence': 90, 'date': '8/04/2017', 'surface_temperature_celcius': 66, 'air_temperature_celcius': 19}
# {'datetime': '2017-05-08T04:26:50', 'confidence': 93, 'date': '8/05/2017', 'surface_temperature_celcius': 72, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-08T04:24:00', 'confidence': 87, 'date': '8/05/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-08T04:20:20', 'confidence': 83, 'date': '8/05/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-08T04:20:10', 'confidence': 86, 'date': '8/05/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-08T04:20:10', 'confidence': 91, 'date': '8/05/2017', 'surface_temperature_celcius': 68, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-08T04:20:10', 'confidence': 97, 'date': '8/05/2017', 'surface_temperature_celcius': 81, 'air_temperature_celcius': 12}
# {'datetime': '2017-03-09T13:23:40', 'confidence': 86, 'date': '9/03/2017', 'surface_temperature_celcius': 41, 'air_temperature_celcius': 23}
# {'datetime': '2017-05-09T12:56:40', 'confidence': 81, 'date': '9/05/2017', 'surface_temperature_celcius': 39, 'air_temperature_celcius': 12}
# {'datetime': '2017-05-09T05:02:50', 'confidence': 81, 'date': '9/05/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 12}
# {'datetime': '2017-06-09T04:23:20', 'confidence': 84, 'date': '9/06/2017', 'surface_temperature_celcius': 52, 'air_temperature_celcius': 10}
# {'datetime': '2017-06-09T04:23:16', 'confidence': 86, 'date': '9/06/2017', 'surface_temperature_celcius': 56, 'air_temperature_celcius': 10}
# {'datetime': '2017-11-09T04:16:48', 'confidence': 85, 'date': '9/11/2017', 'surface_temperature_celcius': 59, 'air_temperature_celcius': 14}
# {'datetime': '2017-11-09T04:16:48', 'confidence': 96, 'date': '9/11/2017', 'surface_temperature_celcius': 77, 'air_temperature_celcius': 14}
# {'datetime': '2017-11-09T04:16:44', 'confidence': 87, 'date': '9/11/2017', 'surface_temperature_celcius': 62, 'air_temperature_celcius': 14}
# {'datetime': '2017-11-09T04:16:44', 'confidence': 97, 'date': '9/11/2017', 'surface_temperature_celcius': 80, 'air_temperature_celcius': 14}
# {'datetime': '2017-12-09T00:14:34', 'confidence': 87, 'date': '9/12/2017', 'surface_temperature_celcius': 61, 'air_temperature_celcius': 17}
# {'datetime': '2017-12-09T00:14:34', 'confidence': 81, 'date': '9/12/2017', 'surface_temperature_celcius': 54, 'air_temperature_celcius': 17}
# {'datetime': '2017-12-09T00:14:33', 'confidence': 84, 'date': '9/12/2017', 'surface_temperature_celcius': 58, 'air_temperature_celcius': 17}
# {'datetime': '2017-12-09T00:14:33', 'confidence': 86, 'date': '9/12/2017', 'surface_temperature_celcius': 60, 'air_temperature_celcius': 17}

# %% [markdown]
# __Solution 2e: Find the top 10 records with the highest surface temperature (°C)__

# %% [markdown]
# In this question we have to find the records from hotspot_historic for the highest surface temperatures.

# %% [markdown]
# For this we would use a list and store all the surface temperatures from the hotspot_historic colectio. then we would use basic principle of sorting and find the top 10 highest value records.
#
# Now using regular expressions we can fetch records from the collection for all the temperatures in the list
#
# '\$in' regular expression is used in this solution. Syntax and use of this can be found in mongoDB official Documantation

# %%
surtemplis = [] #this is a list to get the top 10 highest temperatures
for i in db.hotspot_historic.find({},{'_id':0,'surface_temperature_celcius':1}):
    surtemplis.append(i['surface_temperature_celcius'])
surtemplis = list(set(surtemplis))
surtemplis.sort(reverse=True)
surtemplis = surtemplis[:10] #here we have the top 10 highest temperatures

#now we display the data for the top 10 highest temperatures
for i in db.hotspot_historic.find({'surface_temperature_celcius': {'$in': surtemplis}},{'_id':0}):
    print(i)
# Out:
# {'latitude': -34.9938, 'longitude': 141.876, 'datetime': '2017-05-13T04:40:20', 'confidence': 100, 'date': '13/05/2017', 'surface_temperature_celcius': 120}
# {'latitude': -36.2829, 'longitude': 145.825, 'datetime': '2017-05-08T04:20:10', 'confidence': 100, 'date': '8/05/2017', 'surface_temperature_celcius': 115}
# {'latitude': -36.4057, 'longitude': 140.9806, 'datetime': '2017-05-04T04:44:50', 'confidence': 100, 'date': '4/05/2017', 'surface_temperature_celcius': 119}
# {'latitude': -36.6088, 'longitude': 145.2514, 'datetime': '2017-05-03T04:09:40', 'confidence': 100, 'date': '3/05/2017', 'surface_temperature_celcius': 115}
# {'latitude': -36.9318, 'longitude': 143.0907, 'datetime': '2017-05-01T04:14:20', 'confidence': 100, 'date': '1/05/2017', 'surface_temperature_celcius': 122}
# {'latitude': -36.9348, 'longitude': 143.09799999999998, 'datetime': '2017-05-01T04:14:20', 'confidence': 87, 'date': '1/05/2017', 'surface_temperature_celcius': 117}
# {'latitude': -38.1665, 'longitude': 143.062, 'datetime': '2017-04-18T04:52:00', 'confidence': 100, 'date': '18/04/2017', 'surface_temperature_celcius': 124}
# {'latitude': -37.8326, 'longitude': 143.4999, 'datetime': '2017-04-18T04:44:50', 'confidence': 100, 'date': '18/04/2017', 'surface_temperature_celcius': 120}
# {'latitude': -36.6946, 'longitude': 144.7875, 'datetime': '2017-04-18T04:44:50', 'confidence': 100, 'date': '18/04/2017', 'surface_temperature_celcius': 117}
# {'latitude': -36.239000000000004, 'longitude': 143.3972, 'datetime': '2017-04-15T04:14:30', 'confidence': 100, 'date': '15/04/2017', 'surface_temperature_celcius': 116}
# {'latitude': -37.0745, 'longitude': 141.0692, 'datetime': '2017-04-13T04:28:10', 'confidence': 100, 'date': '13/04/2017', 'surface_temperature_celcius': 120}
# {'latitude': -36.6029, 'longitude': 144.6259, 'datetime': '2017-04-13T04:26:50', 'confidence': 100, 'date': '13/04/2017', 'surface_temperature_celcius': 115}
# {'latitude': -37.8545, 'longitude': 142.5132, 'datetime': '2017-04-06T04:21:00', 'confidence': 100, 'date': '6/04/2017', 'surface_temperature_celcius': 115}
# {'latitude': -36.1057, 'longitude': 141.7608, 'datetime': '2017-04-04T04:40:00', 'confidence': 100, 'date': '4/04/2017', 'surface_temperature_celcius': 120}
# {'latitude': -36.343, 'longitude': 142.1986, 'datetime': '2017-04-04T04:32:50', 'confidence': 100, 'date': '4/04/2017', 'surface_temperature_celcius': 123}
# {'latitude': -36.114000000000004, 'longitude': 142.1377, 'datetime': '2017-04-04T04:32:50', 'confidence': 100, 'date': '4/04/2017', 'surface_temperature_celcius': 118}
# {'latitude': -36.3521, 'longitude': 142.2008, 'datetime': '2017-04-04T04:32:40', 'confidence': 100, 'date': '4/04/2017', 'surface_temperature_celcius': 120}
# {'latitude': -37.3716, 'longitude': 145.9065, 'datetime': '2017-04-03T03:52:20', 'confidence': 100, 'date': '3/04/2017', 'surface_temperature_celcius': 115}
# {'latitude': -37.016999999999996, 'longitude': 148.1297, 'datetime': '2017-03-18T03:50:50', 'confidence': 100, 'date': '18/03/2017', 'surface_temperature_celcius': 121}

# %% [markdown]
# __Solution 2f: Find the number of fire in each day. You are required to only display the
# total number of fire and the date in the output__

# %% [markdown]
# To find the number of fires in a day we have to check the number of records for each date in hotspot_historic collection and the number of records for each day gives us the total number of fires.

# %% [markdown]
# Our first step is the to find the number of records for each date in hotspot_historic collection and then find the count of the dates

# %%
hotspotdate = hotspot_historic_sorted[0]['date']
firecount = 0
firelist = []
for i in hotspot_historic_sorted:
    if(i['date'] == hotspotdate):
        firecount+=1
    else:
        tempdic = {}
        tempdic['date'] = hotspotdate
        tempdic['total_number_fire_count'] = firecount
        firecount = 1
        hotspotdate = i['date']
        firelist.append(tempdic)
tempdic = {}
tempdic['date'] = hotspotdate
tempdic['total_number_fire_count'] = firecount
firelist.append(tempdic)

# %% [markdown]
# However out task is not complete here. There could be some dates where no fire incidents would have occured hence we have to find all the dates for which the record is in consideration. For this we use the climate_historic dataframe and use the unique funciton.

# %%
uniqueDates = (sorted(df_climate_historic['date'].unique()))

# %% [markdown]
# Now that we know all the dates for which the data is being considered we now would perform a lookup weather on the date a fire has occured and if not then we append a record which says 0 fire incidents occured.

# %% [markdown]
# This can be done by appending all the unique dates of the firelist to a list. After this we use all the dates in consideration and perform a lookup to see wether a record for the date exists in firelist. If not then we append a record for the date with 0 fire incident count.

# %%
firelist_dates = []
for i in firelist:
    firelist_dates.append(i['date'])
# finding the fire occurences for 0 fire occurences
for i in uniqueDates:
    if i not in firelist_dates:
        tempdic = {}
        tempdic['date'] = i
        tempdic['total_number_fire_count'] = 0
        firelist.append(tempdic)
        
firelist_sorted = sorted(firelist, key = lambda i: i['date'])  

for i in firelist_sorted:
    print(i)
# Out:
# {'date': '1/01/2018', 'total_number_fire_count': 0}
# {'date': '1/02/2017', 'total_number_fire_count': 0}
# {'date': '1/03/2017', 'total_number_fire_count': 0}
# {'date': '1/04/2017', 'total_number_fire_count': 0}
# {'date': '1/05/2017', 'total_number_fire_count': 8}
# {'date': '1/06/2017', 'total_number_fire_count': 1}
# {'date': '1/07/2017', 'total_number_fire_count': 0}
# {'date': '1/08/2017', 'total_number_fire_count': 1}
# {'date': '1/09/2017', 'total_number_fire_count': 0}
# {'date': '1/10/2017', 'total_number_fire_count': 2}
# {'date': '1/11/2017', 'total_number_fire_count': 0}
# {'date': '1/12/2017', 'total_number_fire_count': 0}
# {'date': '10/01/2017', 'total_number_fire_count': 0}
# {'date': '10/02/2017', 'total_number_fire_count': 0}
# {'date': '10/03/2017', 'total_number_fire_count': 3}
# {'date': '10/04/2017', 'total_number_fire_count': 0}
# {'date': '10/05/2017', 'total_number_fire_count': 35}
# {'date': '10/06/2017', 'total_number_fire_count': 0}
# {'date': '10/07/2017', 'total_number_fire_count': 0}
# {'date': '10/08/2017', 'total_number_fire_count': 0}
# {'date': '10/09/2017', 'total_number_fire_count': 3}
# {'date': '10/10/2017', 'total_number_fire_count': 1}
# {'date': '10/11/2017', 'total_number_fire_count': 0}
# {'date': '10/12/2017', 'total_number_fire_count': 0}
# {'date': '11/01/2017', 'total_number_fire_count': 0}
# {'date': '11/02/2017', 'total_number_fire_count': 0}
# {'date': '11/03/2017', 'total_number_fire_count': 0}
# {'date': '11/04/2017', 'total_number_fire_count': 3}
# {'date': '11/05/2017', 'total_number_fire_count': 10}
# {'date': '11/06/2017', 'total_number_fire_count': 0}
# {'date': '11/07/2017', 'total_number_fire_count': 0}
# {'date': '11/08/2017', 'total_number_fire_count': 0}
# {'date': '11/09/2017', 'total_number_fire_count': 0}
# {'date': '11/10/2017', 'total_number_fire_count': 0}
# {'date': '11/11/2017', 'total_number_fire_count': 1}
# {'date': '11/12/2017', 'total_number_fire_count': 0}
# {'date': '12/01/2017', 'total_number_fire_count': 0}
# {'date': '12/02/2017', 'total_number_fire_count': 0}
# {'date': '12/03/2017', 'total_number_fire_count': 3}
# {'date': '12/04/2017', 'total_number_fire_count': 17}
# {'date': '12/05/2017', 'total_number_fire_count': 3}
# {'date': '12/06/2017', 'total_number_fire_count': 0}
# {'date': '12/07/2017', 'total_number_fire_count': 0}
# {'date': '12/08/2017', 'total_number_fire_count': 0}
# {'date': '12/09/2017', 'total_number_fire_count': 0}
# {'date': '12/10/2017', 'total_number_fire_count': 0}
# {'date': '12/11/2017', 'total_number_fire_count': 1}
# {'date': '12/12/2017', 'total_number_fire_count': 0}
# {'date': '13/01/2017', 'total_number_fire_count': 0}
# {'date': '13/02/2017', 'total_number_fire_count': 0}
# {'date': '13/03/2017', 'total_number_fire_count': 0}
# {'date': '13/04/2017', 'total_number_fire_count': 127}
# {'date': '13/05/2017', 'total_number_fire_count': 19}
# {'date': '13/06/2017', 'total_number_fire_count': 0}
# {'date': '13/07/2017', 'total_number_fire_count': 0}
# {'date': '13/08/2017', 'total_number_fire_count': 2}
# {'date': '13/09/2017', 'total_number_fire_count': 0}
# {'date': '13/10/2017', 'total_number_fire_count': 0}
# {'date': '13/11/2017', 'total_number_fire_count': 2}
# {'date': '13/12/2017', 'total_number_fire_count': 1}
# {'date': '14/01/2017', 'total_number_fire_count': 0}
# {'date': '14/02/2017', 'total_number_fire_count': 0}
# {'date': '14/03/2017', 'total_number_fire_count': 8}
# {'date': '14/04/2017', 'total_number_fire_count': 7}
# {'date': '14/05/2017', 'total_number_fire_count': 0}
# {'date': '14/06/2017', 'total_number_fire_count': 1}
# {'date': '14/07/2017', 'total_number_fire_count': 0}
# {'date': '14/08/2017', 'total_number_fire_count': 0}
# {'date': '14/09/2017', 'total_number_fire_count': 0}
# {'date': '14/10/2017', 'total_number_fire_count': 0}
# {'date': '14/11/2017', 'total_number_fire_count': 1}
# {'date': '14/12/2017', 'total_number_fire_count': 1}
# {'date': '15/01/2017', 'total_number_fire_count': 0}
# {'date': '15/02/2017', 'total_number_fire_count': 0}
# {'date': '15/03/2017', 'total_number_fire_count': 0}
# {'date': '15/04/2017', 'total_number_fire_count': 23}
# {'date': '15/05/2017', 'total_number_fire_count': 30}
# {'date': '15/06/2017', 'total_number_fire_count': 0}
# {'date': '15/07/2017', 'total_number_fire_count': 0}
# {'date': '15/08/2017', 'total_number_fire_count': 0}
# {'date': '15/09/2017', 'total_number_fire_count': 0}
# {'date': '15/10/2017', 'total_number_fire_count': 1}
# {'date': '15/11/2017', 'total_number_fire_count': 0}
# {'date': '15/12/2017', 'total_number_fire_count': 1}
# {'date': '16/01/2017', 'total_number_fire_count': 0}
# {'date': '16/02/2017', 'total_number_fire_count': 0}
# {'date': '16/03/2017', 'total_number_fire_count': 0}
# {'date': '16/04/2017', 'total_number_fire_count': 5}
# {'date': '16/05/2017', 'total_number_fire_count': 0}
# {'date': '16/06/2017', 'total_number_fire_count': 0}
# {'date': '16/07/2017', 'total_number_fire_count': 0}
# {'date': '16/08/2017', 'total_number_fire_count': 0}
# {'date': '16/09/2017', 'total_number_fire_count': 0}
# {'date': '16/10/2017', 'total_number_fire_count': 0}
# {'date': '16/11/2017', 'total_number_fire_count': 0}
# {'date': '16/12/2017', 'total_number_fire_count': 8}
# {'date': '17/01/2017', 'total_number_fire_count': 0}
# {'date': '17/02/2017', 'total_number_fire_count': 0}
# {'date': '17/03/2017', 'total_number_fire_count': 3}
# {'date': '17/04/2017', 'total_number_fire_count': 12}
# {'date': '17/05/2017', 'total_number_fire_count': 0}
# {'date': '17/06/2017', 'total_number_fire_count': 0}
# {'date': '17/07/2017', 'total_number_fire_count': 0}
# {'date': '17/08/2017', 'total_number_fire_count': 0}
# {'date': '17/09/2017', 'total_number_fire_count': 0}
# {'date': '17/10/2017', 'total_number_fire_count': 3}
# {'date': '17/11/2017', 'total_number_fire_count': 0}
# {'date': '17/12/2017', 'total_number_fire_count': 0}
# {'date': '18/01/2017', 'total_number_fire_count': 0}
# {'date': '18/02/2017', 'total_number_fire_count': 0}
# {'date': '18/03/2017', 'total_number_fire_count': 1}
# {'date': '18/04/2017', 'total_number_fire_count': 90}
# {'date': '18/05/2017', 'total_number_fire_count': 0}
# {'date': '18/06/2017', 'total_number_fire_count': 0}
# {'date': '18/07/2017', 'total_number_fire_count': 0}
# {'date': '18/08/2017', 'total_number_fire_count': 0}
# {'date': '18/09/2017', 'total_number_fire_count': 0}
# {'date': '18/10/2017', 'total_number_fire_count': 2}
# {'date': '18/11/2017', 'total_number_fire_count': 0}
# {'date': '18/12/2017', 'total_number_fire_count': 0}
# {'date': '19/01/2017', 'total_number_fire_count': 0}
# {'date': '19/02/2017', 'total_number_fire_count': 0}
# {'date': '19/03/2017', 'total_number_fire_count': 6}
# {'date': '19/04/2017', 'total_number_fire_count': 16}
# {'date': '19/05/2017', 'total_number_fire_count': 0}
# {'date': '19/06/2017', 'total_number_fire_count': 0}
# {'date': '19/07/2017', 'total_number_fire_count': 0}
# {'date': '19/08/2017', 'total_number_fire_count': 0}
# {'date': '19/09/2017', 'total_number_fire_count': 0}
# {'date': '19/10/2017', 'total_number_fire_count': 0}
# {'date': '19/11/2017', 'total_number_fire_count': 0}
# {'date': '19/12/2017', 'total_number_fire_count': 0}
# {'date': '2/01/2017', 'total_number_fire_count': 0}
# {'date': '2/02/2017', 'total_number_fire_count': 0}
# {'date': '2/03/2017', 'total_number_fire_count': 0}
# {'date': '2/04/2017', 'total_number_fire_count': 0}
# {'date': '2/05/2017', 'total_number_fire_count': 2}
# {'date': '2/06/2017', 'total_number_fire_count': 2}
# {'date': '2/07/2017', 'total_number_fire_count': 4}
# {'date': '2/08/2017', 'total_number_fire_count': 1}
# {'date': '2/09/2017', 'total_number_fire_count': 0}
# {'date': '2/10/2017', 'total_number_fire_count': 2}
# {'date': '2/11/2017', 'total_number_fire_count': 0}
# {'date': '2/12/2017', 'total_number_fire_count': 0}
# {'date': '20/01/2017', 'total_number_fire_count': 0}
# {'date': '20/02/2017', 'total_number_fire_count': 0}
# {'date': '20/03/2017', 'total_number_fire_count': 0}
# {'date': '20/04/2017', 'total_number_fire_count': 11}
# {'date': '20/05/2017', 'total_number_fire_count': 0}
# {'date': '20/06/2017', 'total_number_fire_count': 2}
# {'date': '20/07/2017', 'total_number_fire_count': 0}
# {'date': '20/08/2017', 'total_number_fire_count': 0}
# {'date': '20/09/2017', 'total_number_fire_count': 2}
# {'date': '20/10/2017', 'total_number_fire_count': 1}
# {'date': '20/11/2017', 'total_number_fire_count': 0}
# {'date': '20/12/2017', 'total_number_fire_count': 0}
# {'date': '21/01/2017', 'total_number_fire_count': 0}
# {'date': '21/02/2017', 'total_number_fire_count': 0}
# {'date': '21/03/2017', 'total_number_fire_count': 0}
# {'date': '21/04/2017', 'total_number_fire_count': 0}
# {'date': '21/05/2017', 'total_number_fire_count': 0}
# {'date': '21/06/2017', 'total_number_fire_count': 0}
# {'date': '21/07/2017', 'total_number_fire_count': 0}
# {'date': '21/08/2017', 'total_number_fire_count': 0}
# {'date': '21/09/2017', 'total_number_fire_count': 0}
# {'date': '21/10/2017', 'total_number_fire_count': 2}
# {'date': '21/11/2017', 'total_number_fire_count': 1}
# {'date': '21/12/2017', 'total_number_fire_count': 0}
# {'date': '22/01/2017', 'total_number_fire_count': 0}
# {'date': '22/02/2017', 'total_number_fire_count': 0}
# {'date': '22/03/2017', 'total_number_fire_count': 0}
# {'date': '22/04/2017', 'total_number_fire_count': 1}
# {'date': '22/05/2017', 'total_number_fire_count': 6}
# {'date': '22/06/2017', 'total_number_fire_count': 0}
# {'date': '22/07/2017', 'total_number_fire_count': 0}
# {'date': '22/08/2017', 'total_number_fire_count': 0}
# {'date': '22/09/2017', 'total_number_fire_count': 0}
# {'date': '22/10/2017', 'total_number_fire_count': 0}
# {'date': '22/11/2017', 'total_number_fire_count': 2}
# {'date': '22/12/2017', 'total_number_fire_count': 0}
# {'date': '23/01/2017', 'total_number_fire_count': 0}
# {'date': '23/02/2017', 'total_number_fire_count': 0}
# {'date': '23/03/2017', 'total_number_fire_count': 0}
# {'date': '23/04/2017', 'total_number_fire_count': 5}
# {'date': '23/05/2017', 'total_number_fire_count': 2}
# {'date': '23/06/2017', 'total_number_fire_count': 0}
# {'date': '23/07/2017', 'total_number_fire_count': 0}
# {'date': '23/08/2017', 'total_number_fire_count': 0}
# {'date': '23/09/2017', 'total_number_fire_count': 3}
# {'date': '23/10/2017', 'total_number_fire_count': 0}
# {'date': '23/11/2017', 'total_number_fire_count': 2}
# {'date': '23/12/2017', 'total_number_fire_count': 0}
# {'date': '24/01/2017', 'total_number_fire_count': 0}
# {'date': '24/02/2017', 'total_number_fire_count': 0}
# {'date': '24/03/2017', 'total_number_fire_count': 0}
# {'date': '24/04/2017', 'total_number_fire_count': 2}
# {'date': '24/05/2017', 'total_number_fire_count': 0}
# {'date': '24/06/2017', 'total_number_fire_count': 0}
# {'date': '24/07/2017', 'total_number_fire_count': 0}
# {'date': '24/08/2017', 'total_number_fire_count': 0}
# {'date': '24/09/2017', 'total_number_fire_count': 7}
# {'date': '24/10/2017', 'total_number_fire_count': 0}
# {'date': '24/11/2017', 'total_number_fire_count': 0}
# {'date': '24/12/2017', 'total_number_fire_count': 0}
# {'date': '25/01/2017', 'total_number_fire_count': 0}
# {'date': '25/02/2017', 'total_number_fire_count': 0}
# {'date': '25/03/2017', 'total_number_fire_count': 5}
# {'date': '25/04/2017', 'total_number_fire_count': 1}
# {'date': '25/05/2017', 'total_number_fire_count': 0}
# {'date': '25/06/2017', 'total_number_fire_count': 0}
# {'date': '25/07/2017', 'total_number_fire_count': 0}
# {'date': '25/08/2017', 'total_number_fire_count': 0}
# {'date': '25/09/2017', 'total_number_fire_count': 0}
# {'date': '25/10/2017', 'total_number_fire_count': 0}
# {'date': '25/11/2017', 'total_number_fire_count': 0}
# {'date': '25/12/2017', 'total_number_fire_count': 0}
# {'date': '26/01/2017', 'total_number_fire_count': 0}
# {'date': '26/02/2017', 'total_number_fire_count': 0}
# {'date': '26/03/2017', 'total_number_fire_count': 7}
# {'date': '26/04/2017', 'total_number_fire_count': 0}
# {'date': '26/05/2017', 'total_number_fire_count': 1}
# {'date': '26/06/2017', 'total_number_fire_count': 0}
# {'date': '26/07/2017', 'total_number_fire_count': 0}
# {'date': '26/08/2017', 'total_number_fire_count': 0}
# {'date': '26/09/2017', 'total_number_fire_count': 0}
# {'date': '26/10/2017', 'total_number_fire_count': 0}
# {'date': '26/11/2017', 'total_number_fire_count': 0}
# {'date': '26/12/2017', 'total_number_fire_count': 0}
# {'date': '27/01/2017', 'total_number_fire_count': 0}
# {'date': '27/02/2017', 'total_number_fire_count': 0}
# {'date': '27/03/2017', 'total_number_fire_count': 0}
# {'date': '27/04/2017', 'total_number_fire_count': 0}
# {'date': '27/05/2017', 'total_number_fire_count': 0}
# {'date': '27/06/2017', 'total_number_fire_count': 0}
# {'date': '27/07/2017', 'total_number_fire_count': 0}
# {'date': '27/08/2017', 'total_number_fire_count': 0}
# {'date': '27/09/2017', 'total_number_fire_count': 2}
# {'date': '27/10/2017', 'total_number_fire_count': 1}
# {'date': '27/11/2017', 'total_number_fire_count': 0}
# {'date': '27/12/2017', 'total_number_fire_count': 2}
# {'date': '28/01/2017', 'total_number_fire_count': 0}
# {'date': '28/02/2017', 'total_number_fire_count': 0}
# {'date': '28/03/2017', 'total_number_fire_count': 27}
# {'date': '28/04/2017', 'total_number_fire_count': 0}
# {'date': '28/05/2017', 'total_number_fire_count': 0}
# {'date': '28/06/2017', 'total_number_fire_count': 0}
# {'date': '28/07/2017', 'total_number_fire_count': 0}
# {'date': '28/08/2017', 'total_number_fire_count': 0}
# {'date': '28/09/2017', 'total_number_fire_count': 0}
# {'date': '28/10/2017', 'total_number_fire_count': 1}
# {'date': '28/11/2017', 'total_number_fire_count': 0}
# {'date': '28/12/2017', 'total_number_fire_count': 0}
# {'date': '29/01/2017', 'total_number_fire_count': 0}
# {'date': '29/03/2017', 'total_number_fire_count': 0}
# {'date': '29/04/2017', 'total_number_fire_count': 1}
# {'date': '29/05/2017', 'total_number_fire_count': 0}
# {'date': '29/06/2017', 'total_number_fire_count': 0}
# {'date': '29/07/2017', 'total_number_fire_count': 0}
# {'date': '29/08/2017', 'total_number_fire_count': 0}
# {'date': '29/09/2017', 'total_number_fire_count': 1}
# {'date': '29/10/2017', 'total_number_fire_count': 0}
# {'date': '29/11/2017', 'total_number_fire_count': 2}
# {'date': '29/12/2017', 'total_number_fire_count': 0}
# {'date': '3/01/2017', 'total_number_fire_count': 0}
# {'date': '3/02/2017', 'total_number_fire_count': 0}
# {'date': '3/03/2017', 'total_number_fire_count': 0}
# {'date': '3/04/2017', 'total_number_fire_count': 29}
# {'date': '3/05/2017', 'total_number_fire_count': 19}
# {'date': '3/06/2017', 'total_number_fire_count': 0}
# {'date': '3/07/2017', 'total_number_fire_count': 0}
# {'date': '3/08/2017', 'total_number_fire_count': 0}
# {'date': '3/09/2017', 'total_number_fire_count': 0}
# {'date': '3/10/2017', 'total_number_fire_count': 8}
# {'date': '3/11/2017', 'total_number_fire_count': 0}
# {'date': '3/12/2017', 'total_number_fire_count': 0}
# {'date': '30/01/2017', 'total_number_fire_count': 0}
# {'date': '30/03/2017', 'total_number_fire_count': 0}
# {'date': '30/04/2017', 'total_number_fire_count': 0}
# {'date': '30/05/2017', 'total_number_fire_count': 0}
# {'date': '30/06/2017', 'total_number_fire_count': 2}
# {'date': '30/07/2017', 'total_number_fire_count': 0}
# {'date': '30/08/2017', 'total_number_fire_count': 0}
# {'date': '30/09/2017', 'total_number_fire_count': 0}
# {'date': '30/10/2017', 'total_number_fire_count': 0}
# {'date': '30/11/2017', 'total_number_fire_count': 12}
# {'date': '30/12/2017', 'total_number_fire_count': 0}
# {'date': '31/01/2017', 'total_number_fire_count': 0}
# {'date': '31/03/2017', 'total_number_fire_count': 5}
# {'date': '31/05/2017', 'total_number_fire_count': 0}
# {'date': '31/07/2017', 'total_number_fire_count': 1}
# {'date': '31/08/2017', 'total_number_fire_count': 0}
# {'date': '31/10/2017', 'total_number_fire_count': 0}
# {'date': '31/12/2016', 'total_number_fire_count': 0}
# {'date': '31/12/2017', 'total_number_fire_count': 0}
# {'date': '4/01/2017', 'total_number_fire_count': 0}
# {'date': '4/02/2017', 'total_number_fire_count': 0}
# {'date': '4/03/2017', 'total_number_fire_count': 0}
# {'date': '4/04/2017', 'total_number_fire_count': 34}
# {'date': '4/05/2017', 'total_number_fire_count': 42}
# {'date': '4/06/2017', 'total_number_fire_count': 4}
# {'date': '4/07/2017', 'total_number_fire_count': 0}
# {'date': '4/08/2017', 'total_number_fire_count': 0}
# {'date': '4/09/2017', 'total_number_fire_count': 0}
# {'date': '4/10/2017', 'total_number_fire_count': 2}
# {'date': '4/11/2017', 'total_number_fire_count': 0}
# {'date': '4/12/2017', 'total_number_fire_count': 0}
# {'date': '5/01/2017', 'total_number_fire_count': 0}
# {'date': '5/02/2017', 'total_number_fire_count': 0}
# {'date': '5/03/2017', 'total_number_fire_count': 0}
# {'date': '5/04/2017', 'total_number_fire_count': 20}
# {'date': '5/05/2017', 'total_number_fire_count': 10}
# {'date': '5/06/2017', 'total_number_fire_count': 0}
# {'date': '5/07/2017', 'total_number_fire_count': 0}
# {'date': '5/08/2017', 'total_number_fire_count': 0}
# {'date': '5/09/2017', 'total_number_fire_count': 0}
# {'date': '5/10/2017', 'total_number_fire_count': 0}
# {'date': '5/11/2017', 'total_number_fire_count': 3}
# {'date': '5/12/2017', 'total_number_fire_count': 0}
# {'date': '6/01/2017', 'total_number_fire_count': 0}
# {'date': '6/02/2017', 'total_number_fire_count': 0}
# {'date': '6/03/2017', 'total_number_fire_count': 2}
# {'date': '6/04/2017', 'total_number_fire_count': 48}
# {'date': '6/05/2017', 'total_number_fire_count': 7}
# {'date': '6/06/2017', 'total_number_fire_count': 0}
# {'date': '6/07/2017', 'total_number_fire_count': 2}
# {'date': '6/08/2017', 'total_number_fire_count': 0}
# {'date': '6/09/2017', 'total_number_fire_count': 0}
# {'date': '6/10/2017', 'total_number_fire_count': 0}
# {'date': '6/11/2017', 'total_number_fire_count': 0}
# {'date': '6/12/2017', 'total_number_fire_count': 0}
# {'date': '7/01/2017', 'total_number_fire_count': 0}
# {'date': '7/02/2017', 'total_number_fire_count': 0}
# {'date': '7/03/2017', 'total_number_fire_count': 1}
# {'date': '7/04/2017', 'total_number_fire_count': 12}
# {'date': '7/05/2017', 'total_number_fire_count': 0}
# {'date': '7/06/2017', 'total_number_fire_count': 6}
# {'date': '7/07/2017', 'total_number_fire_count': 0}
# {'date': '7/08/2017', 'total_number_fire_count': 0}
# {'date': '7/09/2017', 'total_number_fire_count': 0}
# {'date': '7/10/2017', 'total_number_fire_count': 1}
# {'date': '7/11/2017', 'total_number_fire_count': 0}
# {'date': '7/12/2017', 'total_number_fire_count': 0}
# {'date': '8/01/2017', 'total_number_fire_count': 0}
# {'date': '8/02/2017', 'total_number_fire_count': 0}
# {'date': '8/03/2017', 'total_number_fire_count': 0}
# {'date': '8/04/2017', 'total_number_fire_count': 4}
# {'date': '8/05/2017', 'total_number_fire_count': 6}
# {'date': '8/06/2017', 'total_number_fire_count': 0}
# {'date': '8/07/2017', 'total_number_fire_count': 0}
# {'date': '8/08/2017', 'total_number_fire_count': 0}
# {'date': '8/09/2017', 'total_number_fire_count': 0}
# {'date': '8/10/2017', 'total_number_fire_count': 0}
# {'date': '8/11/2017', 'total_number_fire_count': 0}
# {'date': '8/12/2017', 'total_number_fire_count': 0}
# {'date': '9/01/2017', 'total_number_fire_count': 0}
# {'date': '9/02/2017', 'total_number_fire_count': 0}
# {'date': '9/03/2017', 'total_number_fire_count': 1}
# {'date': '9/04/2017', 'total_number_fire_count': 0}
# {'date': '9/05/2017', 'total_number_fire_count': 2}
# {'date': '9/06/2017', 'total_number_fire_count': 2}
# {'date': '9/07/2017', 'total_number_fire_count': 0}
# {'date': '9/08/2017', 'total_number_fire_count': 0}
# {'date': '9/09/2017', 'total_number_fire_count': 0}
# {'date': '9/10/2017', 'total_number_fire_count': 0}
# {'date': '9/11/2017', 'total_number_fire_count': 4}
# {'date': '9/12/2017', 'total_number_fire_count': 4}

# %% [markdown]
# __Solution 2g: Finding the average surface temperature (°C) for each day. You are required to
# only display average surface temperature (°C) and the date in the output.__

# %% [markdown]
# Here we have to find the average temperatures for each date in the hotspot_historic collection. This can be done by grouping the temperatures based on date and then finding the average of the temperatures for a specific date. The group by is done using aggrgate function and then average is found for each date

# %%
for i in db.hotspot_historic.aggregate([{'$group': {'_id': "$date", 'avgtemp': {'$avg' : '$surface_temperature_celcius'}}}]):
    print(i)
# Out:
# {'_id': '7/03/2017', 'avgtemp': 64.0}
# {'_id': '8/03/2017', 'avgtemp': 51.5}
# {'_id': '9/03/2017', 'avgtemp': 46.666666666666664}
# {'_id': '14/03/2017', 'avgtemp': 65.6}
# {'_id': '17/03/2017', 'avgtemp': 59.5}
# {'_id': '18/03/2017', 'avgtemp': 79.33333333333333}
# {'_id': '24/03/2017', 'avgtemp': 49.0}
# {'_id': '26/03/2017', 'avgtemp': 56.88235294117647}
# {'_id': '19/03/2017', 'avgtemp': 65.57142857142857}
# {'_id': '28/03/2017', 'avgtemp': 60.925925925925924}
# {'_id': '3/04/2017', 'avgtemp': 58.44444444444444}
# {'_id': '4/04/2017', 'avgtemp': 62.57303370786517}
# {'_id': '1/04/2017', 'avgtemp': 46.714285714285715}
# {'_id': '7/04/2017', 'avgtemp': 50.69230769230769}
# {'_id': '12/04/2017', 'avgtemp': 52.69565217391305}
# {'_id': '13/04/2017', 'avgtemp': 58.57983193277311}
# {'_id': '14/04/2017', 'avgtemp': 61.94444444444444}
# {'_id': '6/03/2017', 'avgtemp': 60.5}
# {'_id': '15/04/2017', 'avgtemp': 59.57971014492754}
# {'_id': '19/04/2017', 'avgtemp': 54.16}
# {'_id': '20/04/2017', 'avgtemp': 56.58064516129032}
# {'_id': '23/04/2017', 'avgtemp': 53.89473684210526}
# {'_id': '29/04/2017', 'avgtemp': 63.0}
# {'_id': '25/03/2017', 'avgtemp': 66.0}
# {'_id': '2/05/2017', 'avgtemp': 55.6}
# {'_id': '11/04/2017', 'avgtemp': 46.291666666666664}
# {'_id': '4/05/2017', 'avgtemp': 56.80740740740741}
# {'_id': '5/05/2017', 'avgtemp': 51.70967741935484}
# {'_id': '26/04/2017', 'avgtemp': 34.0}
# {'_id': '9/05/2017', 'avgtemp': 42.46153846153846}
# {'_id': '11/05/2017', 'avgtemp': 59.36842105263158}
# {'_id': '12/05/2017', 'avgtemp': 51.5}
# {'_id': '17/10/2017', 'avgtemp': 51.6}
# {'_id': '1/10/2017', 'avgtemp': 48.25}
# {'_id': '14/05/2017', 'avgtemp': 49.0}
# {'_id': '2/04/2017', 'avgtemp': 45.2}
# {'_id': '15/05/2017', 'avgtemp': 53.950980392156865}
# {'_id': '10/10/2017', 'avgtemp': 53.333333333333336}
# {'_id': '22/05/2017', 'avgtemp': 54.484848484848484}
# {'_id': '1/06/2017', 'avgtemp': 54.0}
# {'_id': '26/05/2017', 'avgtemp': 49.5}
# {'_id': '21/09/2017', 'avgtemp': 40.5}
# {'_id': '3/06/2017', 'avgtemp': 47.0}
# {'_id': '7/06/2017', 'avgtemp': 51.857142857142854}
# {'_id': '20/06/2017', 'avgtemp': 71.16666666666667}
# {'_id': '9/06/2017', 'avgtemp': 49.0}
# {'_id': '1/07/2017', 'avgtemp': 30.5}
# {'_id': '16/06/2017', 'avgtemp': 42.5}
# {'_id': '1/05/2017', 'avgtemp': 68.4}
# {'_id': '3/05/2017', 'avgtemp': 56.796875}
# {'_id': '30/06/2017', 'avgtemp': 44.333333333333336}
# {'_id': '13/03/2017', 'avgtemp': 38.5}
# {'_id': '4/07/2017', 'avgtemp': 40.0}
# {'_id': '6/07/2017', 'avgtemp': 56.0}
# {'_id': '29/07/2017', 'avgtemp': 48.0}
# {'_id': '10/05/2017', 'avgtemp': 52.86842105263158}
# {'_id': '1/08/2017', 'avgtemp': 58.0}
# {'_id': '5/08/2017', 'avgtemp': 40.0}
# {'_id': '13/08/2017', 'avgtemp': 49.0}
# {'_id': '29/03/2017', 'avgtemp': 51.0}
# {'_id': '9/10/2017', 'avgtemp': 44.0}
# {'_id': '20/09/2017', 'avgtemp': 63.6}
# {'_id': '24/09/2017', 'avgtemp': 53.57142857142857}
# {'_id': '10/03/2017', 'avgtemp': 69.375}
# {'_id': '8/10/2017', 'avgtemp': 41.0}
# {'_id': '22/06/2017', 'avgtemp': 46.0}
# {'_id': '2/10/2017', 'avgtemp': 43.57142857142857}
# {'_id': '22/04/2017', 'avgtemp': 54.5}
# {'_id': '16/12/2017', 'avgtemp': 57.8}
# {'_id': '6/10/2017', 'avgtemp': 44.0}
# {'_id': '26/09/2017', 'avgtemp': 33.0}
# {'_id': '10/08/2017', 'avgtemp': 63.0}
# {'_id': '2/06/2017', 'avgtemp': 47.72727272727273}
# {'_id': '27/10/2017', 'avgtemp': 50.4}
# {'_id': '15/10/2017', 'avgtemp': 72.66666666666667}
# {'_id': '18/05/2017', 'avgtemp': 44.142857142857146}
# {'_id': '12/03/2017', 'avgtemp': 88.2}
# {'_id': '16/10/2017', 'avgtemp': 36.0}
# {'_id': '18/10/2017', 'avgtemp': 52.166666666666664}
# {'_id': '8/11/2017', 'avgtemp': 45.5}
# {'_id': '18/06/2017', 'avgtemp': 42.0}
# {'_id': '27/09/2017', 'avgtemp': 49.714285714285715}
# {'_id': '14/07/2017', 'avgtemp': 41.5}
# {'_id': '26/10/2017', 'avgtemp': 44.6}
# {'_id': '31/03/2017', 'avgtemp': 48.72727272727273}
# {'_id': '5/04/2017', 'avgtemp': 53.142857142857146}
# {'_id': '12/12/2017', 'avgtemp': 44.0}
# {'_id': '21/11/2017', 'avgtemp': 59.0}
# {'_id': '25/04/2017', 'avgtemp': 48.666666666666664}
# {'_id': '20/10/2017', 'avgtemp': 50.0}
# {'_id': '15/03/2017', 'avgtemp': 46.0}
# {'_id': '16/04/2017', 'avgtemp': 48.72222222222222}
# {'_id': '13/11/2017', 'avgtemp': 47.0}
# {'_id': '21/10/2017', 'avgtemp': 51.25}
# {'_id': '31/07/2017', 'avgtemp': 47.0}
# {'_id': '7/10/2017', 'avgtemp': 42.0}
# {'_id': '11/06/2017', 'avgtemp': 41.5}
# {'_id': '6/04/2017', 'avgtemp': 61.71186440677966}
# {'_id': '10/09/2017', 'avgtemp': 56.5}
# {'_id': '13/06/2017', 'avgtemp': 41.0}
# {'_id': '9/12/2017', 'avgtemp': 58.25}
# {'_id': '11/11/2017', 'avgtemp': 46.25}
# {'_id': '13/12/2017', 'avgtemp': 60.0}
# {'_id': '23/10/2017', 'avgtemp': 38.0}
# {'_id': '24/04/2017', 'avgtemp': 59.375}
# {'_id': '22/11/2017', 'avgtemp': 61.5}
# {'_id': '23/05/2017', 'avgtemp': 51.2}
# {'_id': '23/09/2017', 'avgtemp': 52.73913043478261}
# {'_id': '28/11/2017', 'avgtemp': 42.0}
# {'_id': '27/12/2017', 'avgtemp': 62.75}
# {'_id': '29/11/2017', 'avgtemp': 60.625}
# {'_id': '24/12/2017', 'avgtemp': 32.0}
# {'_id': '22/09/2017', 'avgtemp': 45.0}
# {'_id': '5/11/2017', 'avgtemp': 58.5}
# {'_id': '2/07/2017', 'avgtemp': 43.5}
# {'_id': '9/11/2017', 'avgtemp': 61.3}
# {'_id': '17/04/2017', 'avgtemp': 50.921052631578945}
# {'_id': '30/11/2017', 'avgtemp': 52.41935483870968}
# {'_id': '8/04/2017', 'avgtemp': 60.75}
# {'_id': '29/09/2017', 'avgtemp': 43.0}
# {'_id': '4/10/2017', 'avgtemp': 49.0}
# {'_id': '13/05/2017', 'avgtemp': 58.611111111111114}
# {'_id': '7/05/2017', 'avgtemp': 50.333333333333336}
# {'_id': '16/05/2017', 'avgtemp': 39.666666666666664}
# {'_id': '25/12/2017', 'avgtemp': 54.0}
# {'_id': '8/05/2017', 'avgtemp': 56.291666666666664}
# {'_id': '17/05/2017', 'avgtemp': 52.0}
# {'_id': '23/11/2017', 'avgtemp': 58.8}
# {'_id': '24/05/2017', 'avgtemp': 40.333333333333336}
# {'_id': '8/12/2017', 'avgtemp': 50.6}
# {'_id': '12/11/2017', 'avgtemp': 53.0}
# {'_id': '3/10/2017', 'avgtemp': 50.0}
# {'_id': '4/06/2017', 'avgtemp': 52.22222222222222}
# {'_id': '15/12/2017', 'avgtemp': 39.0}
# {'_id': '2/08/2017', 'avgtemp': 63.5}
# {'_id': '21/12/2017', 'avgtemp': 46.0}
# {'_id': '18/04/2017', 'avgtemp': 53.36615384615384}
# {'_id': '14/11/2017', 'avgtemp': 52.0}
# {'_id': '10/12/2017', 'avgtemp': 46.0}
# {'_id': '28/10/2017', 'avgtemp': 56.0}
# {'_id': '14/06/2017', 'avgtemp': 53.25}
# {'_id': '5/07/2017', 'avgtemp': 45.0}
# {'_id': '6/05/2017', 'avgtemp': 57.529411764705884}
# {'_id': '14/08/2017', 'avgtemp': 40.8}
# {'_id': '14/12/2017', 'avgtemp': 70.0}

# %% [markdown]
# However in the assignment it is specified that the use of aggregate is not allowed hence mannually we can group the data based on dates by storing it in different lists and then the mean function from numpy library can be used to find the average.

# %%
import numpy
hotspot_historic = []
for i in db.hotspot_historic.find():
    hotspot_historic.append(i)
unique_date = hotspot_historic[0]['date']
avg_temp_date = []
avg_temp = []
# appending the dates in a unique pattern and then finding the average using numpy mean
for i in hotspot_historic:
    if(i['date'] == unique_date):
        avg_temp.append(i['surface_temperature_celcius'])
        
    else:
        tempdic = {}
        tempdic['date'] = unique_date
        tempdic['average_surface_temperature'] = numpy.mean(avg_temp)
        avg_temp = []
        avg_temp_date.append(tempdic)
        unique_date = i['date']
        avg_temp.append(i['surface_temperature_celcius'])
# appending the mean for the last record in the list
tempdic = {}
tempdic['date'] = unique_date
tempdic['average_surface_temperature'] = numpy.mean(avg_temp)
avg_temp_date.append(tempdic)
for i in avg_temp_date:
    print(i)
# Out:
# {'date': '27/12/2017', 'average_surface_temperature': 62.75}
# {'date': '25/12/2017', 'average_surface_temperature': 54.0}
# {'date': '24/12/2017', 'average_surface_temperature': 32.0}
# {'date': '21/12/2017', 'average_surface_temperature': 46.0}
# {'date': '16/12/2017', 'average_surface_temperature': 57.8}
# {'date': '15/12/2017', 'average_surface_temperature': 39.0}
# {'date': '14/12/2017', 'average_surface_temperature': 70.0}
# {'date': '13/12/2017', 'average_surface_temperature': 60.0}
# {'date': '12/12/2017', 'average_surface_temperature': 44.0}
# {'date': '10/12/2017', 'average_surface_temperature': 46.0}
# {'date': '9/12/2017', 'average_surface_temperature': 58.25}
# {'date': '8/12/2017', 'average_surface_temperature': 50.6}
# {'date': '30/11/2017', 'average_surface_temperature': 52.41935483870968}
# {'date': '29/11/2017', 'average_surface_temperature': 60.625}
# {'date': '28/11/2017', 'average_surface_temperature': 42.0}
# {'date': '23/11/2017', 'average_surface_temperature': 58.8}
# {'date': '22/11/2017', 'average_surface_temperature': 61.5}
# {'date': '21/11/2017', 'average_surface_temperature': 59.0}
# {'date': '14/11/2017', 'average_surface_temperature': 52.0}
# {'date': '13/11/2017', 'average_surface_temperature': 47.0}
# {'date': '12/11/2017', 'average_surface_temperature': 53.0}
# {'date': '11/11/2017', 'average_surface_temperature': 46.25}
# {'date': '9/11/2017', 'average_surface_temperature': 61.3}
# {'date': '8/11/2017', 'average_surface_temperature': 45.5}
# {'date': '5/11/2017', 'average_surface_temperature': 58.5}
# {'date': '28/10/2017', 'average_surface_temperature': 56.0}
# {'date': '27/10/2017', 'average_surface_temperature': 50.4}
# {'date': '26/10/2017', 'average_surface_temperature': 44.6}
# {'date': '23/10/2017', 'average_surface_temperature': 38.0}
# {'date': '21/10/2017', 'average_surface_temperature': 51.25}
# {'date': '20/10/2017', 'average_surface_temperature': 50.0}
# {'date': '18/10/2017', 'average_surface_temperature': 52.166666666666664}
# {'date': '17/10/2017', 'average_surface_temperature': 51.6}
# {'date': '16/10/2017', 'average_surface_temperature': 36.0}
# {'date': '15/10/2017', 'average_surface_temperature': 72.66666666666667}
# {'date': '10/10/2017', 'average_surface_temperature': 53.333333333333336}
# {'date': '9/10/2017', 'average_surface_temperature': 44.0}
# {'date': '8/10/2017', 'average_surface_temperature': 41.0}
# {'date': '7/10/2017', 'average_surface_temperature': 42.0}
# {'date': '6/10/2017', 'average_surface_temperature': 44.0}
# {'date': '4/10/2017', 'average_surface_temperature': 49.0}
# {'date': '3/10/2017', 'average_surface_temperature': 50.0}
# {'date': '2/10/2017', 'average_surface_temperature': 43.57142857142857}
# {'date': '1/10/2017', 'average_surface_temperature': 48.25}
# {'date': '29/09/2017', 'average_surface_temperature': 43.0}
# {'date': '27/09/2017', 'average_surface_temperature': 49.714285714285715}
# {'date': '26/09/2017', 'average_surface_temperature': 33.0}
# {'date': '24/09/2017', 'average_surface_temperature': 53.57142857142857}
# {'date': '23/09/2017', 'average_surface_temperature': 52.73913043478261}
# {'date': '22/09/2017', 'average_surface_temperature': 45.0}
# {'date': '21/09/2017', 'average_surface_temperature': 40.5}
# {'date': '20/09/2017', 'average_surface_temperature': 63.6}
# {'date': '10/09/2017', 'average_surface_temperature': 56.5}
# {'date': '14/08/2017', 'average_surface_temperature': 40.8}
# {'date': '13/08/2017', 'average_surface_temperature': 49.0}
# {'date': '10/08/2017', 'average_surface_temperature': 63.0}
# {'date': '5/08/2017', 'average_surface_temperature': 40.0}
# {'date': '2/08/2017', 'average_surface_temperature': 63.5}
# {'date': '1/08/2017', 'average_surface_temperature': 58.0}
# {'date': '31/07/2017', 'average_surface_temperature': 47.0}
# {'date': '29/07/2017', 'average_surface_temperature': 48.0}
# {'date': '14/07/2017', 'average_surface_temperature': 41.5}
# {'date': '6/07/2017', 'average_surface_temperature': 56.0}
# {'date': '5/07/2017', 'average_surface_temperature': 45.0}
# {'date': '4/07/2017', 'average_surface_temperature': 40.0}
# {'date': '2/07/2017', 'average_surface_temperature': 43.5}
# {'date': '1/07/2017', 'average_surface_temperature': 30.5}
# {'date': '30/06/2017', 'average_surface_temperature': 44.333333333333336}
# {'date': '22/06/2017', 'average_surface_temperature': 46.0}
# {'date': '20/06/2017', 'average_surface_temperature': 71.16666666666667}
# {'date': '18/06/2017', 'average_surface_temperature': 42.0}
# {'date': '16/06/2017', 'average_surface_temperature': 42.5}
# {'date': '14/06/2017', 'average_surface_temperature': 53.25}
# {'date': '13/06/2017', 'average_surface_temperature': 41.0}
# {'date': '11/06/2017', 'average_surface_temperature': 41.5}
# {'date': '9/06/2017', 'average_surface_temperature': 49.0}
# {'date': '7/06/2017', 'average_surface_temperature': 51.857142857142854}
# {'date': '4/06/2017', 'average_surface_temperature': 52.22222222222222}
# {'date': '3/06/2017', 'average_surface_temperature': 47.0}
# {'date': '2/06/2017', 'average_surface_temperature': 47.72727272727273}
# {'date': '1/06/2017', 'average_surface_temperature': 54.0}
# {'date': '26/05/2017', 'average_surface_temperature': 49.5}
# {'date': '24/05/2017', 'average_surface_temperature': 40.333333333333336}
# {'date': '23/05/2017', 'average_surface_temperature': 51.2}
# {'date': '22/05/2017', 'average_surface_temperature': 54.484848484848484}
# {'date': '18/05/2017', 'average_surface_temperature': 44.142857142857146}
# {'date': '17/05/2017', 'average_surface_temperature': 52.0}
# {'date': '16/05/2017', 'average_surface_temperature': 39.666666666666664}
# {'date': '15/05/2017', 'average_surface_temperature': 53.950980392156865}
# {'date': '14/05/2017', 'average_surface_temperature': 49.0}
# {'date': '13/05/2017', 'average_surface_temperature': 58.611111111111114}
# {'date': '12/05/2017', 'average_surface_temperature': 51.5}
# {'date': '11/05/2017', 'average_surface_temperature': 59.36842105263158}
# {'date': '10/05/2017', 'average_surface_temperature': 52.86842105263158}
# {'date': '9/05/2017', 'average_surface_temperature': 42.46153846153846}
# {'date': '8/05/2017', 'average_surface_temperature': 56.291666666666664}
# {'date': '7/05/2017', 'average_surface_temperature': 50.333333333333336}
# {'date': '6/05/2017', 'average_surface_temperature': 57.529411764705884}
# {'date': '5/05/2017', 'average_surface_temperature': 51.70967741935484}
# {'date': '4/05/2017', 'average_surface_temperature': 56.80740740740741}
# {'date': '3/05/2017', 'average_surface_temperature': 56.796875}
# {'date': '2/05/2017', 'average_surface_temperature': 55.6}
# {'date': '1/05/2017', 'average_surface_temperature': 68.4}
# {'date': '29/04/2017', 'average_surface_temperature': 63.0}
# {'date': '26/04/2017', 'average_surface_temperature': 34.0}
# {'date': '25/04/2017', 'average_surface_temperature': 48.666666666666664}
# {'date': '24/04/2017', 'average_surface_temperature': 59.375}
# {'date': '23/04/2017', 'average_surface_temperature': 53.89473684210526}
# {'date': '22/04/2017', 'average_surface_temperature': 54.5}
# {'date': '20/04/2017', 'average_surface_temperature': 56.58064516129032}
# {'date': '19/04/2017', 'average_surface_temperature': 54.16}
# {'date': '18/04/2017', 'average_surface_temperature': 53.36615384615384}
# {'date': '17/04/2017', 'average_surface_temperature': 50.921052631578945}
# {'date': '16/04/2017', 'average_surface_temperature': 48.72222222222222}
# {'date': '15/04/2017', 'average_surface_temperature': 59.57971014492754}
# {'date': '14/04/2017', 'average_surface_temperature': 61.94444444444444}
# {'date': '13/04/2017', 'average_surface_temperature': 58.57983193277311}
# {'date': '12/04/2017', 'average_surface_temperature': 52.69565217391305}
# {'date': '11/04/2017', 'average_surface_temperature': 46.291666666666664}
# {'date': '8/04/2017', 'average_surface_temperature': 60.75}
# {'date': '7/04/2017', 'average_surface_temperature': 50.69230769230769}
# {'date': '6/04/2017', 'average_surface_temperature': 61.71186440677966}
# {'date': '5/04/2017', 'average_surface_temperature': 53.142857142857146}
# {'date': '4/04/2017', 'average_surface_temperature': 62.57303370786517}
# {'date': '3/04/2017', 'average_surface_temperature': 58.44444444444444}
# {'date': '2/04/2017', 'average_surface_temperature': 45.2}
# {'date': '1/04/2017', 'average_surface_temperature': 46.714285714285715}
# {'date': '31/03/2017', 'average_surface_temperature': 48.72727272727273}
# {'date': '29/03/2017', 'average_surface_temperature': 51.0}
# {'date': '28/03/2017', 'average_surface_temperature': 60.925925925925924}
# {'date': '26/03/2017', 'average_surface_temperature': 56.88235294117647}
# {'date': '25/03/2017', 'average_surface_temperature': 66.0}
# {'date': '24/03/2017', 'average_surface_temperature': 49.0}
# {'date': '19/03/2017', 'average_surface_temperature': 65.57142857142857}
# {'date': '18/03/2017', 'average_surface_temperature': 79.33333333333333}
# {'date': '17/03/2017', 'average_surface_temperature': 59.5}
# {'date': '15/03/2017', 'average_surface_temperature': 46.0}
# {'date': '14/03/2017', 'average_surface_temperature': 65.6}
# {'date': '13/03/2017', 'average_surface_temperature': 38.5}
# {'date': '12/03/2017', 'average_surface_temperature': 88.2}
# {'date': '10/03/2017', 'average_surface_temperature': 69.375}
# {'date': '9/03/2017', 'average_surface_temperature': 46.666666666666664}
# {'date': '8/03/2017', 'average_surface_temperature': 51.5}
# {'date': '7/03/2017', 'average_surface_temperature': 64.0}
# {'date': '6/03/2017', 'average_surface_temperature': 60.5}
