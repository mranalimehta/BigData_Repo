# %%
import pandas as pd
import random
df = pd.read_csv('hotspot_TERRA_streaming.csv')

# %%
data = df

# %%
result_list = []

for i in data.index:
    data_dict = {}
    data_dict['latitude'] = data['latitude'][i]
    data_dict['longitude'] = data['longitude'][i]
    data_dict['surface_temperature_celcius'] = str(data['surface_temperature_celcius'][i])
    data_dict['confidence'] = str(data['confidence'][i])
    result_list.append(data_dict)

# %%
for data in result_list:
    print(data)
# Out:
# {'latitude': -37.966, 'longitude': 145.05100000000002, 'surface_temperature_celcius': '68', 'confidence': '78'}
# {'latitude': -35.541, 'longitude': 143.311, 'surface_temperature_celcius': '63', 'confidence': '82'}
# {'latitude': -35.554, 'longitude': 143.30700000000002, 'surface_temperature_celcius': '53', 'confidence': '67'}
# {'latitude': -35.543, 'longitude': 143.316, 'surface_temperature_celcius': '67', 'confidence': '86'}
# {'latitude': -37.708, 'longitude': 145.1, 'surface_temperature_celcius': '54', 'confidence': '80'}
# {'latitude': -35.646, 'longitude': 142.282, 'surface_temperature_celcius': '32', 'confidence': '65'}
# {'latitude': -38.075, 'longitude': 143.76, 'surface_temperature_celcius': '46', 'confidence': '72'}
# {'latitude': -37.635999999999996, 'longitude': 149.33, 'surface_temperature_celcius': '43', 'confidence': '94'}
# {'latitude': -37.624, 'longitude': 149.332, 'surface_temperature_celcius': '33', 'confidence': '69'}
# ...

# %%
# import statements

from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt


def publish_message(producer_instance, topic_name, key, data):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=data)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x:dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'hotspot_streaming'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    for data in result_list:
        publish_message(producer, topic, 'terra_data', data)
        sleep(random.randint(10,30))
# Out:
# Publishing records..
# Message published successfully. Data: {'latitude': -37.966, 'longitude': 145.05100000000002, 'surface_temperature_celcius': '68', 'confidence': '78'}
# Message published successfully. Data: {'latitude': -35.541, 'longitude': 143.311, 'surface_temperature_celcius': '63', 'confidence': '82'}
# Message published successfully. Data: {'latitude': -35.554, 'longitude': 143.30700000000002, 'surface_temperature_celcius': '53', 'confidence': '67'}
# Message published successfully. Data: {'latitude': -35.543, 'longitude': 143.316, 'surface_temperature_celcius': '67', 'confidence': '86'}
# Message published successfully. Data: {'latitude': -37.708, 'longitude': 145.1, 'surface_temperature_celcius': '54', 'confidence': '80'}
# Message published successfully. Data: {'latitude': -35.646, 'longitude': 142.282, 'surface_temperature_celcius': '32', 'confidence': '65'}
# ...
